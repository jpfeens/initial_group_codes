# %% [markdown]
# # Run this in an OQ Console as an administrator
#
# **To install python packages, use `pip` in your OQ Console**

# %%
# Sample notebook for a deterministic seismic assessment for Venus SLC at Leinster, WA
# This project was looking at very short distances to consider potential effects for mining-induced seismicity
# As a result, the GMM developed for induced seismicity are weighted preferrentially. Additionally,
# GMMs were used for specific magnitude ranges (i.e. 3-4, 4-5, 5-6) and were weighted accordingly for each range.
#
# -------------------------
# Author: Erin Todd  
# Last Edited: 24 February 2021 (E.Todd)
# --------------------------


# !!! COPY THIS NOTEBOOK TO YOUR PROJECT FOLDER TO USE AS AN EXAMPLE. 
# !!! THIS NOTEBOOK IS NOT INTENDED TO BE A WORKING VERSION - IT IS AN EXAMPLE ONLY.

# %%
import os
userdir = os.environ['USERPROFILE']
onedrive_folder = os.environ['ONEDRIVE']
# Set filepath to your github repository
github_dir = os.path.join(userdir,'Documents','GitHub','initial_group_codes','python_tools')

import sys
# Add github repository to system path
if github_dir not in sys.path:
    sys.path.insert(0,github_dir)
print(sys.path)
# Out:
# ['C:\\Users\\ertodd\\Documents\\GitHub\\initial_group_codes\\python_tools', 'C:\\Users\\ertodd\\Documents\\GitHub\\initial_group_codes\\sample_notebooks', 'C:\\Users\\ertodd\\Anaconda3\\python38.zip', 'C:\\Users\\ertodd\\Anaconda3\\DLLs', 'C:\\Users\\ertodd\\Anaconda3\\lib', 'C:\\Users\\ertodd\\Anaconda3', '', 'C:\\Users\\ertodd\\Anaconda3\\lib\\site-packages', 'C:\\Users\\ertodd\\Anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\ertodd\\Anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\ertodd\\Anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\ertodd\\Anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\ertodd\\.ipython']

# %%
from openquake.hazardlib.gsim import get_available_gsims
from openquake.hazardlib.gsim.base import RuptureContext, SitesContext, DistancesContext
from openquake.hazardlib import const
from openquake.hazardlib.imt import PGA, SA
import pandas as pd
import numpy as np    
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
# Out:
# In C:\Users\ertodd\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\ertodd\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\ertodd\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\ertodd\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\ertodd\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\ertodd\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\ertodd\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\ertodd\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
from deterministic_tools import calculate_ground_motions

# %% [markdown]
# # Initialise project details

# %%
# Set project top directory
topdir = os.path.join(userdir, 'Golder Associates','20373366, BHP NiW NLN Mining Impacts on TSF2 Leinster WA - Deterministic_Seismic_Assessment')
figdir = os.path.join(topdir,'figures')

# Project name
proj_name = 'VenusSLC'

# site location - unknown
#sLat =
#sLon = 

# site soil condition
vs30 = '800' #m/s

# Identify magnitudes to be used in this DSA
mag_bin_width = 0.2
magnitudes = np.around(np.arange(3.0,6.0+mag_bin_width,mag_bin_width),decimals=1)

# Identify distances to be used in this DSA 
# !!! See note at top of notebook about why these distances are so short - normally these would be presented in kilometres)
distances = np.asarray([300, 500, 750, 1000]) # in m

# %% [markdown]
# # Look at tectonic region type for all existing OpenQuake GMMs

# %%
gmpe_list = get_available_gsims()
gmpe_list.pop('AlAtikSigmaModel')
gmpe_list.pop('AmeriEtAl2017RepiStressDrop')
gmpe_list.pop('AmeriEtAl2017RjbStressDrop')
gmpe_list.pop('AvgGMPE')
gmpe_list.pop('CY14SiteTerm')
gmpe_list.pop('Eurocode8Amplification')
gmpe_list.pop('Eurocode8AmplificationDefault')
gmpe_list.pop('GMPETable')
gmpe_list.pop('GenericGmpeAvgSA')
gmpe_list.pop('ModifiableGMPE')
gmpe_list.pop('NBCC2015_AA13')
gmpe_list.pop('NGAEastGMPE')
gmpe_list.pop('NGAEastGMPETotalSigma')
gmpe_list.pop('NGAEastUSGSGMPE')
gmpe_list.pop('NRCan15SiteTerm')
gmpe_list.pop('NRCan15SiteTermLinear')
gmpe_list.pop('NSHMP2014')
gmpe_list.pop('PitilakisEtAl2018')
gmpe_list.pop('PitilakisEtAl2020')
gmpe_list.pop('SandikkayaDinsever2018')
gmpe_list.pop('SplitSigmaGMPE')
gmpe_list.pop('TromansEtAl2019')
gmpe_list.pop('TromansEtAl2019SigmaMu')
gmpe_list.pop('WesternCan15Low')
gmpe_list.pop('WesternCan15Mid')
gmpe_list.pop('WesternCan15RjbLow')
gmpe_list.pop('WesternCan15RjbMid')
gmpe_list.pop('WesternCan15RjbUpp')
gmpe_list.pop('WesternCan15Upp')
for gmmName in gmpe_list:
    print(gmmName)
    print('\t',gmpe_list[gmmName]().DEFINED_FOR_TECTONIC_REGION_TYPE)
# Out:
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:437: DeprecationWarning: AkkarEtAl2013 is deprecated - use AkkarEtAlRjb2014 instead
#   warnings.warn(msg, DeprecationWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Atkinson2015 is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: AtkinsonMacias2009NSHMP2014 is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: BCHydroSERASInter is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: BCHydroSERASInterHigh is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: BCHydroSERASInterLow is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: BCHydroSERASSlab is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: BCHydroSERASSlabHigh is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: BCHydroSERASSlabLow is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013AdditionalSigma is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013LHC is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013VolcLHC is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013bChchCBD is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013bChchCBDAdditionalSigma is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013bChchEast is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013bChchEastAdditionalSigma is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013bChchMaps is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013bChchMapsAdditionalSigma is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013bChchNorth is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013bChchNorthAdditionalSigma is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013bChchWest is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Bradley2013bChchWestAdditionalSigma is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:450: AdaptedWarning: ChiouYoungs2014ACME2019 is not intended for general use and the behaviour may not be as expected - the user is liable for their application
#   warnings.warn(msg, AdaptedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: ConvertitoEtAl2012Geysers is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DostEtAl2004 is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DostEtAl2004BommerAdaptation is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015Repi is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015RepiHR is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015Repi_50bars is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015Rhyp is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015RhypHR is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015Rhyp_50bars is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015Rjb is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015RjbHR is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015RjbHR_50bars is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015Rjb_50bars is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015Rrup is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015RrupHR is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015RrupHR_50bars is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: DrouetAlpes2015Rrup_50bars is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: EasternCan15Low is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: EasternCan15Mid is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: EasternCan15Upp is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: Gupta2010SSlab is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: HongGoda2007 is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: KothaEtAl2020 is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: KothaEtAl2020SERA is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: KothaEtAl2020SERASlopeGeology is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: KothaEtAl2020Site is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: KothaEtAl2020Slope is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: McGarrFletcher2005 is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: McVerry2006Chch is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# AbrahamsonEtAl2014
# 	 Active Shallow Crust
# AbrahamsonEtAl2014RegCHN
# 	 Active Shallow Crust
# AbrahamsonEtAl2014RegJPN
# 	 Active Shallow Crust
# AbrahamsonEtAl2014RegTWN
# 	 Active Shallow Crust
# AbrahamsonEtAl2015SInter
# 	 Subduction Interface
# AbrahamsonEtAl2015SInterHigh
# 	 Subduction Interface
# AbrahamsonEtAl2015SInterLow
# 	 Subduction Interface
# AbrahamsonEtAl2015SSlab
# 	 Subduction IntraSlab
# AbrahamsonEtAl2015SSlabHigh
# 	 Subduction IntraSlab
# AbrahamsonEtAl2015SSlabLow
# 	 Subduction IntraSlab
# AbrahamsonEtAl2018SInter
# 	 Subduction Interface
# AbrahamsonEtAl2018SInterHigh
# 	 Subduction Interface
# AbrahamsonEtAl2018SInterLow
# 	 Subduction Interface
# AbrahamsonEtAl2018SSlab
# 	 Subduction IntraSlab
# AbrahamsonEtAl2018SSlabHigh
# 	 Subduction IntraSlab
# AbrahamsonEtAl2018SSlabLow
# 	 Subduction IntraSlab
# AbrahamsonSilva1997
# 	 Active Shallow Crust
# AbrahamsonSilva2008
# 	 Active Shallow Crust
# AfshariStewart2016
# 	 Active Shallow Crust
# AfshariStewart2016Japan
# 	 Active Shallow Crust
# AkkarBommer2010
# 	 Active Shallow Crust
# AkkarBommer2010SWISS01
# 	 Active Shallow Crust
# AkkarBommer2010SWISS04
# 	 Active Shallow Crust
# AkkarBommer2010SWISS08
# 	 Active Shallow Crust
# AkkarCagnan2010
# 	 Active Shallow Crust
# AkkarEtAl2013
# 	 Active Shallow Crust
# AkkarEtAlRepi2014
# 	 Active Shallow Crust
# AkkarEtAlRhyp2014
# 	 Active Shallow Crust
# AkkarEtAlRjb2014
# 	 Active Shallow Crust
# AkkarEtAlRjb2014Armenia
# 	 Active Shallow Crust
# Allen2012
# 	 Stable Shallow Crust
# AllenEtAl2012
# 	 Active Shallow Crust
# AllenEtAl2012Rhypo
# 	 Active Shallow Crust
# AmeriEtAl2017Repi
# 	 Active Shallow Crust
# AmeriEtAl2017Rjb
# 	 Active Shallow Crust
# Atkinson2008prime
# 	 Stable Shallow Crust
# Atkinson2010Hawaii
# 	 Volcanic
# Atkinson2015
# 	 Induced
# AtkinsonBoore1995GSCBest
# 	 Stable Shallow Crust
# AtkinsonBoore1995GSCLowerLimit
# 	 Stable Shallow Crust
# AtkinsonBoore1995GSCUpperLimit
# 	 Stable Shallow Crust
# AtkinsonBoore2003SInter
# 	 Subduction Interface
# AtkinsonBoore2003SInterNSHMP2008
# 	 Subduction Interface
# AtkinsonBoore2003SSlab
# 	 Subduction IntraSlab
# AtkinsonBoore2003SSlabCascadia
# 	 Subduction IntraSlab
# AtkinsonBoore2003SSlabCascadiaNSHMP2008
# 	 Subduction IntraSlab
# AtkinsonBoore2003SSlabJapan
# 	 Subduction IntraSlab
# AtkinsonBoore2003SSlabJapanNSHMP2008
# 	 Subduction IntraSlab
# AtkinsonBoore2003SSlabNSHMP2008
# 	 Subduction IntraSlab
# AtkinsonBoore2006
# 	 Stable Shallow Crust
# AtkinsonBoore2006MblgAB1987bar140NSHMP2008
# 	 Stable Shallow Crust
# AtkinsonBoore2006MblgAB1987bar200NSHMP2008
# 	 Stable Shallow Crust
# AtkinsonBoore2006MblgJ1996bar140NSHMP2008
# 	 Stable Shallow Crust
# AtkinsonBoore2006MblgJ1996bar200NSHMP2008
# 	 Stable Shallow Crust
# AtkinsonBoore2006Modified2011
# 	 Stable Shallow Crust
# AtkinsonBoore2006Mwbar140NSHMP2008
# 	 Stable Shallow Crust
# AtkinsonBoore2006Mwbar200NSHMP2008
# 	 Stable Shallow Crust
# AtkinsonBoore2006SGS
# 	 Stable Shallow Crust
# AtkinsonMacias2009
# 	 Subduction Interface
# AtkinsonMacias2009NSHMP2014
# 	 Subduction Interface
# BCHydroSERASInter
# 	 Subduction Interface
# BCHydroSERASInterHigh
# 	 Subduction Interface
# BCHydroSERASInterLow
# 	 Subduction Interface
# BCHydroSERASSlab
# 	 Subduction IntraSlab
# BCHydroSERASSlabHigh
# 	 Subduction IntraSlab
# BCHydroSERASSlabLow
# 	 Subduction IntraSlab
# BergeThierryEtAl2003Ms
# 	 Active Shallow Crust
# BergeThierryEtAl2003MwL_GBL
# 	 Active Shallow Crust
# BergeThierryEtAl2003MwL_ITA
# 	 Active Shallow Crust
# BergeThierryEtAl2003MwL_MED
# 	 Active Shallow Crust
# BergeThierryEtAl2003MwW
# 	 Active Shallow Crust
# BergeThierryEtAl2003SIGMA
# 	 Active Shallow Crust
# BindiEtAl2011
# 	 Active Shallow Crust
# BindiEtAl2011Ita19Low
# 	 Active Shallow Crust
# BindiEtAl2011Ita19Upp
# 	 Active Shallow Crust
# BindiEtAl2011scaled
# 	 Active Shallow Crust
# BindiEtAl2014Rhyp
# 	 Active Shallow Crust
# BindiEtAl2014RhypEC8
# 	 Active Shallow Crust
# BindiEtAl2014RhypEC8NoSOF
# 	 Active Shallow Crust
# BindiEtAl2014RhypEC8scaled
# 	 Active Shallow Crust
# BindiEtAl2014Rjb
# 	 Active Shallow Crust
# BindiEtAl2014RjbArmenia
# 	 Active Shallow Crust
# BindiEtAl2014RjbEC8
# 	 Active Shallow Crust
# BindiEtAl2014RjbEC8NoSOF
# 	 Active Shallow Crust
# BindiEtAl2017Rhypo
# 	 Stable Shallow Crust
# BindiEtAl2017Rjb
# 	 Stable Shallow Crust
# BommerEtAl2009RSD
# 	 Active Shallow Crust
# BooreAtkinson2008
# 	 Active Shallow Crust
# BooreAtkinson2011
# 	 Active Shallow Crust
# BooreEtAl1993GSCBest
# 	 Active Shallow Crust
# BooreEtAl1993GSCLowerLimit
# 	 Active Shallow Crust
# BooreEtAl1993GSCUpperLimit
# 	 Active Shallow Crust
# BooreEtAl1997ArbitraryHorizontal
# 	 Active Shallow Crust
# BooreEtAl1997ArbitraryHorizontalUnspecified
# 	 Active Shallow Crust
# BooreEtAl1997GeometricMean
# 	 Active Shallow Crust
# BooreEtAl1997GeometricMeanUnspecified
# 	 Active Shallow Crust
# BooreEtAl2014
# 	 Active Shallow Crust
# BooreEtAl2014CaliforniaBasin
# 	 Active Shallow Crust
# BooreEtAl2014CaliforniaBasinNoSOF
# 	 Active Shallow Crust
# BooreEtAl2014HighQ
# 	 Active Shallow Crust
# BooreEtAl2014HighQCaliforniaBasin
# 	 Active Shallow Crust
# BooreEtAl2014HighQCaliforniaBasinNoSOF
# 	 Active Shallow Crust
# BooreEtAl2014HighQJapanBasin
# 	 Active Shallow Crust
# BooreEtAl2014HighQJapanBasinNoSOF
# 	 Active Shallow Crust
# BooreEtAl2014HighQNoSOF
# 	 Active Shallow Crust
# BooreEtAl2014JapanBasin
# 	 Active Shallow Crust
# BooreEtAl2014JapanBasinNoSOF
# 	 Active Shallow Crust
# BooreEtAl2014LowQ
# 	 Active Shallow Crust
# BooreEtAl2014LowQArmenia
# 	 Active Shallow Crust
# BooreEtAl2014LowQCaliforniaBasin
# 	 Active Shallow Crust
# BooreEtAl2014LowQCaliforniaBasinNoSOF
# 	 Active Shallow Crust
# BooreEtAl2014LowQJapanBasin
# 	 Active Shallow Crust
# BooreEtAl2014LowQJapanBasinNoSOF
# 	 Active Shallow Crust
# BooreEtAl2014LowQNoSOF
# 	 Active Shallow Crust
# BooreEtAl2014NoSOF
# 	 Active Shallow Crust
# BozorgniaCampbell2016
# 	 Active Shallow Crust
# BozorgniaCampbell2016AveQJapanSite
# 	 Active Shallow Crust
# BozorgniaCampbell2016HighQ
# 	 Active Shallow Crust
# BozorgniaCampbell2016HighQJapanSite
# 	 Active Shallow Crust
# BozorgniaCampbell2016LowQ
# 	 Active Shallow Crust
# BozorgniaCampbell2016LowQJapanSite
# 	 Active Shallow Crust
# Bradley2013
# 	 Active Shallow Crust
# Bradley2013AdditionalSigma
# 	 Active Shallow Crust
# Bradley2013LHC
# 	 Active Shallow Crust
# Bradley2013Volc
# 	 Volcanic
# Bradley2013VolcLHC
# 	 Volcanic
# Bradley2013bChchCBD
# 	 Active Shallow Crust
# Bradley2013bChchCBDAdditionalSigma
# 	 Active Shallow Crust
# Bradley2013bChchEast
# 	 Active Shallow Crust
# Bradley2013bChchEastAdditionalSigma
# 	 Active Shallow Crust
# Bradley2013bChchMaps
# 	 Active Shallow Crust
# Bradley2013bChchMapsAdditionalSigma
# 	 Active Shallow Crust
# Bradley2013bChchNorth
# 	 Active Shallow Crust
# Bradley2013bChchNorthAdditionalSigma
# 	 Active Shallow Crust
# Bradley2013bChchWest
# 	 Active Shallow Crust
# Bradley2013bChchWestAdditionalSigma
# 	 Active Shallow Crust
# Campbell1997
# 	 Active Shallow Crust
# Campbell2003
# 	 Stable Shallow Crust
# Campbell2003MblgAB1987NSHMP2008
# 	 Stable Shallow Crust
# Campbell2003MblgJ1996NSHMP2008
# 	 Stable Shallow Crust
# Campbell2003MwNSHMP2008
# 	 Stable Shallow Crust
# Campbell2003SHARE
# 	 Stable Shallow Crust
# CampbellBozorgnia2003NSHMP2007
# 	 Active Shallow Crust
# CampbellBozorgnia2008
# 	 Active Shallow Crust
# CampbellBozorgnia2008Arbitrary
# 	 Active Shallow Crust
# CampbellBozorgnia2014
# 	 Active Shallow Crust
# CampbellBozorgnia2014HighQ
# 	 Active Shallow Crust
# CampbellBozorgnia2014HighQJapanSite
# 	 Active Shallow Crust
# CampbellBozorgnia2014JapanSite
# 	 Active Shallow Crust
# CampbellBozorgnia2014LowQ
# 	 Active Shallow Crust
# CampbellBozorgnia2014LowQJapanSite
# 	 Active Shallow Crust
# CauzziEtAl2014
# 	 Active Shallow Crust
# CauzziEtAl2014Armenia
# 	 Active Shallow Crust
# CauzziEtAl2014Eurocode8
# 	 Active Shallow Crust
# CauzziEtAl2014Eurocode8NoSOF
# 	 Active Shallow Crust
# CauzziEtAl2014Eurocode8scaled
# 	 Active Shallow Crust
# CauzziEtAl2014FixedVs30
# 	 Active Shallow Crust
# CauzziEtAl2014FixedVs30NoSOF
# 	 Active Shallow Crust
# CauzziEtAl2014NoSOF
# 	 Active Shallow Crust
# CauzziEtAl2014RhypoGermany
# 	 Active Shallow Crust
# CauzziFaccioli2008
# 	 Active Shallow Crust
# CauzziFaccioli2008SWISS01
# 	 Active Shallow Crust
# CauzziFaccioli2008SWISS04
# 	 Active Shallow Crust
# CauzziFaccioli2008SWISS08
# 	 Active Shallow Crust
# ChiouYoungs2008
# 	 Active Shallow Crust
# ChiouYoungs2008SWISS01
# 	 Active Shallow Crust
# ChiouYoungs2008SWISS04
# 	 Active Shallow Crust
# ChiouYoungs2008SWISS06
# 	 Active Shallow Crust
# ChiouYoungs2014
# 	 Active Shallow Crust
# ChiouYoungs2014ACME2019
# 	 Active Shallow Crust
# ChiouYoungs2014Armenia
# 	 Active Shallow Crust
# ChiouYoungs2014NearFaultEffect
# 	 Active Shallow Crust
# ChiouYoungs2014PEER
# 	 Active Shallow Crust
# ClimentEtAl1994
# 	 Active Shallow Crust
# ConvertitoEtAl2012Geysers
# 	 Geothermal
# DerrasEtAl2014
# 	 Active Shallow Crust
# DerrasEtAl2014RhypoGermany
# 	 Active Shallow Crust
# DostEtAl2004
# 	 Induced
# DostEtAl2004BommerAdaptation
# 	 Induced
# DouglasEtAl2013StochasticSD001Q1800K005
# 	 Geothermal
# DouglasEtAl2013StochasticSD001Q1800K020
# 	 Geothermal
# DouglasEtAl2013StochasticSD001Q1800K040
# 	 Geothermal
# DouglasEtAl2013StochasticSD001Q1800K060
# 	 Geothermal
# DouglasEtAl2013StochasticSD001Q200K005
# 	 Geothermal
# DouglasEtAl2013StochasticSD001Q200K020
# 	 Geothermal
# DouglasEtAl2013StochasticSD001Q200K040
# 	 Geothermal
# DouglasEtAl2013StochasticSD001Q200K060
# 	 Geothermal
# DouglasEtAl2013StochasticSD001Q600K005
# 	 Geothermal
# DouglasEtAl2013StochasticSD001Q600K020
# 	 Geothermal
# DouglasEtAl2013StochasticSD001Q600K040
# 	 Geothermal
# DouglasEtAl2013StochasticSD001Q600K060
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q1800K005
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q1800K020
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q1800K040
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q1800K060
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q200K005
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q200K020
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q200K040
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q200K060
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q600K005
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q600K020
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q600K040
# 	 Geothermal
# DouglasEtAl2013StochasticSD010Q600K060
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q1800K005
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q1800K020
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q1800K040
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q1800K060
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q200K005
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q200K020
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q200K040
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q200K060
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q600K005
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q600K020
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q600K040
# 	 Geothermal
# DouglasEtAl2013StochasticSD100Q600K060
# 	 Geothermal
# DowrickRhoades2005Asc
# 	 Active Shallow Crust
# DowrickRhoades2005SInter
# 	 Subduction Interface
# DowrickRhoades2005SSlab
# 	 Subduction IntraSlab
# DowrickRhoades2005Volc
# 	 Volcanic
# DrouetAlpes2015Repi
# 	 Active Shallow Crust
# DrouetAlpes2015RepiHR
# 	 Active Shallow Crust
# DrouetAlpes2015Repi_50bars
# 	 Active Shallow Crust
# DrouetAlpes2015Rhyp
# 	 Active Shallow Crust
# DrouetAlpes2015RhypHR
# 	 Active Shallow Crust
# DrouetAlpes2015Rhyp_50bars
# 	 Active Shallow Crust
# DrouetAlpes2015Rjb
# 	 Active Shallow Crust
# DrouetAlpes2015RjbHR
# 	 Active Shallow Crust
# DrouetAlpes2015RjbHR_50bars
# 	 Active Shallow Crust
# DrouetAlpes2015Rjb_50bars
# 	 Active Shallow Crust
# DrouetAlpes2015Rrup
# 	 Active Shallow Crust
# DrouetAlpes2015RrupHR
# 	 Active Shallow Crust
# DrouetAlpes2015RrupHR_50bars
# 	 Active Shallow Crust
# DrouetAlpes2015Rrup_50bars
# 	 Active Shallow Crust
# DrouetBrazil2015
# 	 Stable Shallow Crust
# DrouetBrazil2015withDepth
# 	 Stable Shallow Crust
# EasternCan15Low
# 	 Stable Shallow Crust
# EasternCan15Mid
# 	 Stable Shallow Crust
# EasternCan15Upp
# 	 Stable Shallow Crust
# EdwardsFah2013Alpine10Bars
# 	 Active Shallow Crust
# EdwardsFah2013Alpine120Bars
# 	 Active Shallow Crust
# EdwardsFah2013Alpine20Bars
# 	 Active Shallow Crust
# EdwardsFah2013Alpine30Bars
# 	 Active Shallow Crust
# EdwardsFah2013Alpine50Bars
# 	 Active Shallow Crust
# EdwardsFah2013Alpine60Bars
# 	 Active Shallow Crust
# EdwardsFah2013Alpine75Bars
# 	 Active Shallow Crust
# EdwardsFah2013Alpine90Bars
# 	 Active Shallow Crust
# EdwardsFah2013Foreland10Bars
# 	 Active Shallow Crust
# EdwardsFah2013Foreland120Bars
# 	 Active Shallow Crust
# EdwardsFah2013Foreland20Bars
# 	 Active Shallow Crust
# EdwardsFah2013Foreland30Bars
# 	 Active Shallow Crust
# EdwardsFah2013Foreland50Bars
# 	 Active Shallow Crust
# EdwardsFah2013Foreland60Bars
# 	 Active Shallow Crust
# EdwardsFah2013Foreland75Bars
# 	 Active Shallow Crust
# EdwardsFah2013Foreland90Bars
# 	 Active Shallow Crust
# FaccioliEtAl2010
# 	 Active Shallow Crust
# FrankelEtAl1996MblgAB1987NSHMP2008
# 	 Stable Shallow Crust
# FrankelEtAl1996MblgJ1996NSHMP2008
# 	 Stable Shallow Crust
# FrankelEtAl1996MwNSHMP2008
# 	 Stable Shallow Crust
# FukushimaTanaka1990
# 	 Active Shallow Crust
# FukushimaTanakaSite1990
# 	 Active Shallow Crust
# GarciaEtAl2005SSlab
# 	 Subduction IntraSlab
# GarciaEtAl2005SSlabVert
# 	 Subduction IntraSlab
# Geomatrix1993SSlabNSHMP2008
# 	 Subduction IntraSlab
# GhofraniAtkinson2014
# 	 Subduction Interface
# GhofraniAtkinson2014Cascadia
# 	 Subduction Interface
# GhofraniAtkinson2014CascadiaLower
# 	 Subduction Interface
# GhofraniAtkinson2014CascadiaUpper
# 	 Subduction Interface
# GhofraniAtkinson2014Lower
# 	 Subduction Interface
# GhofraniAtkinson2014Upper
# 	 Subduction Interface
# GulerceEtAl2017
# 	 Active Shallow Crust
# GulerceEtAl2017RegCHN
# 	 Active Shallow Crust
# GulerceEtAl2017RegITA
# 	 Active Shallow Crust
# GulerceEtAl2017RegJPN
# 	 Active Shallow Crust
# GulerceEtAl2017RegMID
# 	 Active Shallow Crust
# GulerceEtAl2017RegTWN
# 	 Active Shallow Crust
# Gupta2010SSlab
# 	 Subduction IntraSlab
# HongGoda2007
# 	 Active Shallow Crust
# Idriss2014
# 	 Active Shallow Crust
# KaleEtAl2015Armenia
# 	 Active Shallow Crust
# KaleEtAl2015Iran
# 	 Active Shallow Crust
# KaleEtAl2015Turkey
# 	 Active Shallow Crust
# Kanno2006Deep
# 	 Subduction IntraSlab
# Kanno2006Shallow
# 	 Subduction Interface
# KothaEtAl2016
# 	 Active Shallow Crust
# KothaEtAl2016Armenia
# 	 Active Shallow Crust
# KothaEtAl2016Italy
# 	 Active Shallow Crust
# KothaEtAl2016Other
# 	 Active Shallow Crust
# KothaEtAl2016Turkey
# 	 Active Shallow Crust
# KothaEtAl2020
# 	 Active Shallow Crust
# KothaEtAl2020SERA
# 	 Active Shallow Crust
# KothaEtAl2020SERASlopeGeology
# 	 Active Shallow Crust
# KothaEtAl2020Site
# 	 Active Shallow Crust
# KothaEtAl2020Slope
# 	 Active Shallow Crust
# LanzanoLuzi2019deep
# 	 Volcanic
# LanzanoLuzi2019shallow
# 	 Volcanic
# Lin2009
# 	 Active Shallow Crust
# Lin2009AdjustedSigma
# 	 Active Shallow Crust
# LinLee2008SInter
# 	 Subduction Interface
# LinLee2008SSlab
# 	 Subduction IntraSlab
# McGarrFletcher2005
# 	 Induced
# McVerry2006Asc
# 	 Active Shallow Crust
# McVerry2006AscSC
# 	 Active Shallow Crust
# McVerry2006Chch
# 	 Active Shallow Crust
# McVerry2006ChchAdditionalSigma
# 	 Active Shallow Crust
# McVerry2006ChchStressDrop
# 	 Active Shallow Crust
# McVerry2006SInter
# 	 Subduction Interface
# McVerry2006SInterSC
# 	 Subduction Interface
# McVerry2006SSlab
# 	 Subduction IntraSlab
# McVerry2006SSlabSC
# 	 Subduction IntraSlab
# McVerry2006Volc
# 	 Volcanic
# McVerry2006VolcSC
# 	 Volcanic
# MegawatiEtAl2003
# 	 Active Shallow Crust
# MegawatiPan2010
# 	 Subduction Interface
# MontalvaEtAl2016SInter
# 	 Subduction Interface
# MontalvaEtAl2016SSlab
# 	 Subduction IntraSlab
# MontalvaEtAl2017SInter
# 	 Subduction Interface
# MontalvaEtAl2017SSlab
# 	 Subduction IntraSlab
# MorikawaFujiwara2013Crustal
# 	 Active Shallow Crust
# MorikawaFujiwara2013SubInterface
# 	 Subduction Interface
# MorikawaFujiwara2013SubInterfaceNE
# 	 Subduction Interface
# MorikawaFujiwara2013SubInterfaceSW
# 	 Subduction Interface
# MorikawaFujiwara2013SubSlab
# 	 Subduction IntraSlab
# MorikawaFujiwara2013SubSlabNE
# 	 Subduction IntraSlab
# MorikawaFujiwara2013SubSlabSW
# 	 Subduction IntraSlab
# MultiGMPE
#
# MunsonThurber1997
# 	 Volcanic
# MunsonThurber1997Hawaii
# 	 Volcanic
# MunsonThurber1997Vector
# 	 Volcanic
# NathEtAl2012Lower
# 	 Subduction Interface
# NathEtAl2012Upper
# 	 Subduction Interface
# OceanicCan15Low
# 	 Active Shallow Crust
# OceanicCan15Mid
# 	 Active Shallow Crust
# OceanicCan15Upp
# 	 Active Shallow Crust
# PankowPechmann2004
# 	 Active Shallow Crust
# PezeshkEtAl2011
# 	 Stable Shallow Crust
# PezeshkEtAl2011NEHRPBC
# 	 Stable Shallow Crust
# RaghukanthIyengar2007
# 	 Stable Shallow Crust
# RaghukanthIyengar2007KoynaWarna
# 	 Stable Shallow Crust
# RaghukanthIyengar2007Southern
# 	 Stable Shallow Crust
# RaghukanthIyengar2007WesternCentral
# 	 Stable Shallow Crust
# RietbrockEdwards2019Low
# 	 Stable Shallow Crust
# RietbrockEdwards2019Mean
# 	 Stable Shallow Crust
# RietbrockEdwards2019Up
# 	 Stable Shallow Crust
# RietbrockEtAl2013MagDependent
# 	 Stable Shallow Crust
# RietbrockEtAl2013SelfSimilar
# 	 Stable Shallow Crust
# SERA2020Craton
# 	 Stable Shallow Crust
# SInterCan15Low
# 	 Subduction Interface
# SInterCan15Mid
# 	 Subduction Interface
# SInterCan15Upp
# 	 Subduction Interface
# SSlabCan15Low
# 	 Subduction IntraSlab
# SSlabCan15Mid
# 	 Subduction IntraSlab
# SSlabCan15Upp
# 	 Subduction IntraSlab
# SadighEtAl1997
# 	 Active Shallow Crust
# ShahjoueiPezeshk2016
# 	 Stable Shallow Crust
# SharmaEtAl2009
# 	 Active Shallow Crust
# SiMidorikawa1999Asc
# 	 Active Shallow Crust
# SiMidorikawa1999SInter
# 	 Subduction Interface
# SiMidorikawa1999SInterNorthEastCorrection
# 	 Subduction Interface
# SiMidorikawa1999SInterSouthWestCorrection
# 	 Subduction Interface
# SiMidorikawa1999SSlab
# 	 Subduction IntraSlab
# SiMidorikawa1999SSlabNorthEastCorrection
# 	 Subduction IntraSlab
# SiMidorikawa1999SSlabSouthWestCorrection
# 	 Subduction IntraSlab
# SilvaEtAl2002DoubleCornerSaturation
# 	 Stable Shallow Crust
# SilvaEtAl2002MblgAB1987NSHMP2008
# 	 Stable Shallow Crust
# SilvaEtAl2002MblgJ1996NSHMP2008
# 	 Stable Shallow Crust
# SilvaEtAl2002MwNSHMP2008
# 	 Stable Shallow Crust
# SilvaEtAl2002SingleCornerSaturation
# 	 Stable Shallow Crust
# SkarlatoudisEtAlSSlab2013
# 	 Subduction IntraSlab
# SomervilleEtAl2001NSHMP2008
# 	 Stable Shallow Crust
# SomervilleEtAl2009NonCratonic
# 	 Stable Shallow Crust
# SomervilleEtAl2009YilgarnCraton
# 	 Stable Shallow Crust
# StewartEtAl2016
# 	 Active Shallow Crust
# StewartEtAl2016NoSOF
# 	 Active Shallow Crust
# StewartEtAl2016RegCHN
# 	 Active Shallow Crust
# StewartEtAl2016RegCHNNoSOF
# 	 Active Shallow Crust
# StewartEtAl2016RegJPN
# 	 Active Shallow Crust
# StewartEtAl2016RegJPNNoSOF
# 	 Active Shallow Crust
# TavakoliPezeshk2005
# 	 Stable Shallow Crust
# TavakoliPezeshk2005MblgAB1987NSHMP2008
# 	 Stable Shallow Crust
# TavakoliPezeshk2005MblgJ1996NSHMP2008
# 	 Stable Shallow Crust
# TavakoliPezeshk2005MwNSHMP2008
# 	 Stable Shallow Crust
# ToroEtAl1997MblgNSHMP2008
# 	 Stable Shallow Crust
# ToroEtAl1997MwNSHMP2008
# 	 Stable Shallow Crust
# ToroEtAl2002
# 	 Stable Shallow Crust
# ToroEtAl2002SHARE
# 	 Stable Shallow Crust
# TravasarouEtAl2003
# 	 Active Shallow Crust
# TusaLanger2016RepiBA08DE
# 	 Volcanic
# TusaLanger2016RepiBA08SE
# 	 Volcanic
# TusaLanger2016RepiSP87DE
# 	 Volcanic
# TusaLanger2016RepiSP87SE
# 	 Volcanic
# TusaLanger2016Rhypo
# 	 Volcanic
# VanHoutteEtAl2018RSD
# 	 Active Shallow Crust
# YenierAtkinson2015ACME2019
# 	 Active Shallow Crust
# YenierAtkinson2015BSSA
# 	 Active Shallow Crust
# YoungsEtAl1997GSCSSlabBest
# 	 Subduction IntraSlab
# YoungsEtAl1997GSCSSlabLowerLimit
# 	 Subduction IntraSlab
# YoungsEtAl1997GSCSSlabUpperLimit
# 	 Subduction IntraSlab
# YoungsEtAl1997SInter
# 	 Subduction Interface
# YoungsEtAl1997SInterNSHMP2008
# 	 Subduction Interface
# YoungsEtAl1997SSlab
# 	 Subduction IntraSlab
# YuEtAl2013Ms
# 	 Active Shallow Crust
# YuEtAl2013MsEastern
# 	 Stable Shallow Crust
# YuEtAl2013MsStable
# 	 Stable Shallow Crust
# YuEtAl2013MsTibet
# 	 Active Shallow Crust
# YuEtAl2013Mw
# 	 Active Shallow Crust
# YuEtAl2013MwEastern
# 	 Stable Shallow Crust
# YuEtAl2013MwStable
# 	 Stable Shallow Crust
# YuEtAl2013MwTibet
# 	 Active Shallow Crust
# ZalachorisRathje2019
# 	 Induced
# ZhaoEtAl2006Asc
# 	 Active Shallow Crust
# ZhaoEtAl2006AscSGS
# 	 Active Shallow Crust
# ZhaoEtAl2006AscSWISS03
# 	 Active Shallow Crust
# ZhaoEtAl2006AscSWISS05
# 	 Active Shallow Crust
# ZhaoEtAl2006AscSWISS08
# 	 Active Shallow Crust
# ZhaoEtAl2006SInter
# 	 Subduction Interface
# ZhaoEtAl2006SInterCascadia
# 	 Subduction Interface
# ZhaoEtAl2006SInterNSHMP2008
# 	 Subduction Interface
# ZhaoEtAl2006SSlab
# 	 Subduction IntraSlab
# ZhaoEtAl2006SSlabCascadia
# 	 Subduction IntraSlab
# ZhaoEtAl2006SSlabNSHMP2014
# 	 Subduction IntraSlab
# ZhaoEtAl2016Asc
# 	 Active Shallow Crust
# ZhaoEtAl2016AscSiteSigma
# 	 Active Shallow Crust
# ZhaoEtAl2016SInter
# 	 Subduction Interface
# ZhaoEtAl2016SInterSiteSigma
# 	 Subduction Interface
# ZhaoEtAl2016SSlab
# 	 Subduction IntraSlab
# ZhaoEtAl2016SSlabSiteSigma
# 	 Subduction IntraSlab
# ZhaoEtAl2016UpperMantle
# 	 Upper Mantle
# ZhaoEtAl2016UpperMantleSiteSigma
# 	 Upper Mantle
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: McVerry2006ChchAdditionalSigma is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: McVerry2006ChchStressDrop is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:437: DeprecationWarning: MontalvaEtAl2016SInter is deprecated - use MontalvaEtAl2017SInter instead
#   warnings.warn(msg, DeprecationWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:437: DeprecationWarning: MontalvaEtAl2016SSlab is deprecated - use MontalvaEtAl2017SSlab instead
#   warnings.warn(msg, DeprecationWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: OceanicCan15Low is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: OceanicCan15Mid is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: OceanicCan15Upp is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: PankowPechmann2004 is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: RaghukanthIyengar2007 is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: RaghukanthIyengar2007KoynaWarna is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: RaghukanthIyengar2007Southern is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: RaghukanthIyengar2007WesternCentral is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:445: ExperimentalWarning: SERA2020Craton is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: SInterCan15Low is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: SInterCan15Mid is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: SInterCan15Upp is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: SSlabCan15Low is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: SSlabCan15Mid is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: SSlabCan15Upp is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: ShahjoueiPezeshk2016 is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)
# C:\Users\ertodd\Anaconda3\lib\site-packages\openquake\hazardlib\gsim\base.py:441: NotVerifiedWarning: TravasarouEtAl2003 is not independently verified - the user is liable for their application
#   warnings.warn(msg, NotVerifiedWarning)

# %% [markdown]
# # Identify selected GMMs and their weights

# %%
# format: {gmm_name : [3.0-4.0 weight, 4.0-5.0 weight, 5.0-6.0 weight]}
gmms = {'ChiouYoungs2014' : [0.0,0.0,0.0], #trt = active shallow crust
        'Atkinson2015' : [0.3,0.4,0.0], #trt = INDUCED
        'DostEtAl2004' : [0.0,0.0,0.0], # trt = INDUCED
        'DouglasEtAl2013StochasticSD001Q200K005' : [0.0,0.0,0.0], #wrong Vs30 kind of conditions due to geothermal areas
        'McGarrFletcher2005' : [0.3,0.0,0.0],
        'ZalachorisRathje2019' : [0.2,0.2,0.0], 
        'Allen2012' : [0.0,0.0,0.0], 
        'AtkinsonBoore2006' : [0.0,0.0,0.0], 
        'AtkinsonBoore2006Modified2011' : [0.0,0.0,0.0], 
        'SomervilleEtAl2009YilgarnCraton' : [0.0,0.0,0.0], 
        'ZhaoEtAl2006AscSWISS05' : [0.0,0.0,0.0], 
        'BooreEtAl2014' : [0.0,0.0,0.0],
        #'BooreEtAl2014LowQ' : [0.0,0.0,0.0]
}

# %%
# format: {gmm_name : [3.0-4.0 weight, 4.0-5.0 weight, 5.0-6.0 weight]} 
# The length of the values list is len(np.arange(3.0,6.2,0.2))
gmms_weight_dict = {'McGarrFletcher2005' : ([0.3]*5) + ([0.0]*11),
                    'Atkinson2015' : ([0.3]*5) + ([0.4]*5) + ([0.0]*6),
                    'ZalachorisRathje2019' : ([0.2]*5) + ([0.2]*5) + ([0.0]*6),
                    'DostEtAl2004' : [0.0]*len(magnitudes), # trt = INDUCED
                    'DouglasEtAl2013StochasticSD001Q200K005' : [0.0]*len(magnitudes), 
                    'Allen2012' : ([0.0]*5) + ([0.1]*5) + ([(1/7)]*6), 
                    'AtkinsonBoore2006' : ([0.1]*5) + ([0.05]*5) + ([(1/7)]*6), 
                    'AtkinsonBoore2006Modified2011' : ([0.1]*5) + ([0.05]*5) + ([(1/7)]*6),
                    'SomervilleEtAl2009YilgarnCraton' : ([0.0]*10) + ([(1/7)]*6),  
                    'ZhaoEtAl2006AscSWISS05' : ([0.0]*5) + ([0.1]*5) + ([(1/7)]*6), 
                    'BooreEtAl2014' : ([0.0]*5) + ([0.05]*5) + ([(1/7)]*6),
                    'ChiouYoungs2014' : ([0.0]*5) + ([0.05]*5) + ([(1/7)]*6)
                   }

# %% [markdown]
# # Identify the input parameters required for each selected GMM

# %%
# Define the GMM list
gmm_list = []
for selected_gmm in gmms_weight_dict:
    gmm_list.append(gmpe_list[selected_gmm]())

for gmm in gmm_list:
    # Each GMM has the following information
    print(gmm)
    print('\tTectonic region type:',gmm.DEFINED_FOR_TECTONIC_REGION_TYPE)
    print('\tRupture params:',gmm.REQUIRES_RUPTURE_PARAMETERS)
    print('\tDistance params:',gmm.REQUIRES_DISTANCES)
    print('\tSite params:',gmm.REQUIRES_SITES_PARAMETERS)
    print('\tIMTs:',gmm.DEFINED_FOR_INTENSITY_MEASURE_TYPES)
# Out:
# [McGarrFletcher2005]
# 	Tectonic region type: Induced
# 	Rupture params: frozenset({'mag'})
# 	Distance params: frozenset({'rhypo'})
# 	Site params: frozenset()
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.SA'>, <class 'openquake.hazardlib.imt.PGV'>})
# [Atkinson2015]
# 	Tectonic region type: Induced
# 	Rupture params: frozenset({'mag'})
# 	Distance params: frozenset({'rhypo'})
# 	Site params: frozenset()
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.SA'>, <class 'openquake.hazardlib.imt.PGV'>})
# [ZalachorisRathje2019]
# 	Tectonic region type: Induced
# 	Rupture params: frozenset({'mag', 'rake'})
# 	Distance params: frozenset({'rjb', 'rhypo'})
# 	Site params: frozenset({'vs30'})
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.SA'>, <class 'openquake.hazardlib.imt.PGV'>})
# [DostEtAl2004]
# 	Tectonic region type: Induced
# 	Rupture params: frozenset({'mag'})
# 	Distance params: frozenset({'rhypo'})
# 	Site params: frozenset()
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.PGV'>})
# [DouglasEtAl2013StochasticSD001Q200K005]
# 	Tectonic region type: Geothermal
# 	Rupture params: frozenset({'mag'})
# 	Distance params: frozenset({'rhypo'})
# 	Site params: frozenset()
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.SA'>, <class 'openquake.hazardlib.imt.PGV'>})
# [Allen2012]
# 	Tectonic region type: Stable Shallow Crust
# 	Rupture params: frozenset({'mag', 'hypo_depth'})
# 	Distance params: frozenset({'rrup'})
# 	Site params: frozenset()
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.SA'>})
# [AtkinsonBoore2006]
# 	Tectonic region type: Stable Shallow Crust
# 	Rupture params: frozenset({'mag'})
# 	Distance params: frozenset({'rrup'})
# 	Site params: frozenset({'vs30'})
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.SA'>, <class 'openquake.hazardlib.imt.PGV'>})
# [AtkinsonBoore2006Modified2011]
# 	Tectonic region type: Stable Shallow Crust
# 	Rupture params: frozenset({'mag'})
# 	Distance params: frozenset({'rrup'})
# 	Site params: frozenset({'vs30'})
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.SA'>, <class 'openquake.hazardlib.imt.PGV'>})
# [SomervilleEtAl2009YilgarnCraton]
# 	Tectonic region type: Stable Shallow Crust
# 	Rupture params: frozenset({'mag'})
# 	Distance params: frozenset({'rjb'})
# 	Site params: frozenset()
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.SA'>, <class 'openquake.hazardlib.imt.PGV'>})
# [ZhaoEtAl2006AscSWISS05]
# 	Tectonic region type: Active Shallow Crust
# 	Rupture params: frozenset({'mag', 'rake', 'hypo_depth'})
# 	Distance params: frozenset({'rrup'})
# 	Site params: frozenset({'vs30'})
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.SA'>})
# [BooreEtAl2014]
# 	Tectonic region type: Active Shallow Crust
# 	Rupture params: frozenset({'mag', 'rake'})
# 	Distance params: frozenset({'rjb'})
# 	Site params: frozenset({'vs30'})
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.SA'>, <class 'openquake.hazardlib.imt.PGV'>})
# [ChiouYoungs2014]
# 	Tectonic region type: Active Shallow Crust
# 	Rupture params: frozenset({'mag', 'dip', 'rake', 'ztor'})
# 	Distance params: frozenset({'rrup', 'rjb', 'rx'})
# 	Site params: frozenset({'vs30measured', 'z1pt0', 'vs30'})
# 	IMTs: frozenset({<class 'openquake.hazardlib.imt.PGA'>, <class 'openquake.hazardlib.imt.SA'>, <class 'openquake.hazardlib.imt.PGV'>})

# %% [markdown]
# # Calculate PGA values
#
# **GMM input parameters could be read in as a dataframe from a file containing the required inputs**
#
# Example:
#
# > Fault_name	Rrup	Rjb	Rx	Rhypo	Depth	Distance	Magnitude	Dip	Rake	Ztor	Vs30	Z1pt0	Vs30measured
# M3.0_R300	0.3	0.3	0	0.3	0.3	0.3	3.0	45	90	0.3	760	33.7	0
# ![image-2.png](attachment:image-2.png)
#
# > Note: vs30measured is a switch where 0 = inferred and 1 = measured

# %%
# Initialise results directory
gmm_results = dict.fromkeys([str(x).replace('[','').replace(']','') for x in gmm_list])

for gmm in gmm_list:
    gmm_label = str(gmm).replace('[','').replace(']','')
    print(gmm_label)
    
    #Set GMM input parameters
    rctx = RuptureContext()
    rctx.dip = 45
    rctx.rake = 90
    sctx = SitesContext()
    sctx.vs30measured = 0 # 0 = inferred; 1 = measured
    dctx = DistancesContext()

    # Intensity measurements
    imts = [PGA()]

    # StdDev type
    stddev_types = [const.StdDev.TOTAL]
    
    if gmm_label == 'ZalachorisRathje2019':
        sctx.vs30 = np.asarray([760.0])
        sctx.z1pt0 = np.asarray([33.7]) # Calculated from Kalakamos et al 2011
    else: 
        sctx.vs30 = np.asarray([800.0])
        sctx.z1pt0 = np.asarray([26.8]) # Calculated from Kalakamos et al 2011
    
    # In this example, the site is directly about the source by the distances initialised above
    gmm_results[gmm_label] = dict.fromkeys(distances)
    for d in distances:
        dist_km = np.asarray([d/1000]) # distance in km
        dctx.rjb = dist_km
        dctx.rrup = dist_km
        dctx.rhypo = dist_km
        dctx.rx = dist_km
        rctx.hypo_depth = dist_km
        rctx.ztor = dist_km
        
        gmm_results[gmm_label][d] = dict.fromkeys(magnitudes)
        for m in magnitudes:
            rctx.mag = np.asarray([m])
            #Compute PGA ground motions for each magnitude/distances pair
            gmm_results[gmm_label][d][m] = calculate_ground_motions(gmm, sctx, rctx, dctx, imts, stddev_types)
# Out:
# McGarrFletcher2005
# Atkinson2015
# ZalachorisRathje2019
# DostEtAl2004
# DouglasEtAl2013StochasticSD001Q200K005
# Allen2012
# AtkinsonBoore2006
# AtkinsonBoore2006Modified2011
# SomervilleEtAl2009YilgarnCraton
# ZhaoEtAl2006AscSWISS05
# BooreEtAl2014
# ChiouYoungs2014

# %% [markdown]
# ## Look at the PGA results

# %%
for k1 in gmm_results.keys():
    print(k1)
    for k2 in gmm_results[k1].keys():
        print('\t',k2)
        for k3 in gmm_results[k1][k2].keys():
            print('\t\t',k3)
            for k4,v in gmm_results[k1][k2][k3].items():
                print('\t\t\t',k4,':',v)
#print(gmm_results)
# Out:
# McGarrFletcher2005
# 	 300
# 		 3.0
# 			 mean : [0.46891057]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [1.42590314]
# 			 mean_minus_1sd : [0.15420201]
# 		 3.2
# 			 mean : [0.70399573]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [2.14077007]
# 			 mean_minus_1sd : [0.23151014]
# 		 3.4
# 			 mean : [1.05693925]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [3.21403073]
# 			 mean_minus_1sd : [0.34757619]
# 		 3.6
# 			 mean : [1.58682862]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [4.82536338]
# 			 mean_minus_1sd : [0.52183118]
# 		 3.8
# 			 mean : [2.38237446]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [7.24452682]
# 			 mean_minus_1sd : [0.78344773]
# 		 4.0
# 			 mean : [3.57676185]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [10.87652154]
# 			 mean_minus_1sd : [1.17622397]
# 		 4.2
# 			 mean : [5.36994731]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [16.32939236]
# 			 mean_minus_1sd : [1.76591593]
# 		 4.4
# 			 mean : [8.06213422]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [24.51602323]
# 			 mean_minus_1sd : [2.65124599]
# 		 4.6
# 			 mean : [12.10403092]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [36.80696636]
# 			 mean_minus_1sd : [3.98043031]
# 		 4.8
# 			 mean : [18.17230529]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [55.25989104]
# 			 mean_minus_1sd : [5.97599223]
# 		 5.0
# 			 mean : [27.28286815]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [82.96406523]
# 			 mean_minus_1sd : [8.97201569]
# 		 5.2
# 			 mean : [40.96095035]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [124.55754055]
# 			 mean_minus_1sd : [13.47007532]
# 		 5.4
# 			 mean : [61.49644692]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [187.00362457]
# 			 mean_minus_1sd : [20.22320686]
# 		 5.6
# 			 mean : [92.32727639]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [280.75663224]
# 			 mean_minus_1sd : [30.36197542]
# 		 5.8
# 			 mean : [138.61493456]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [421.51207885]
# 			 mean_minus_1sd : [45.58374729]
# 		 6.0
# 			 mean : [208.1085984]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [632.83432059]
# 			 mean_minus_1sd : [68.43685198]
# 	 500
# 		 3.0
# 			 mean : [0.22040679]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [0.67023171]
# 			 mean_minus_1sd : [0.07248113]
# 		 3.2
# 			 mean : [0.33090625]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [1.00624786]
# 			 mean_minus_1sd : [0.10881906]
# 		 3.4
# 			 mean : [0.49680387]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [1.51072344]
# 			 mean_minus_1sd : [0.16337476]
# 		 3.6
# 			 mean : [0.74587314]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [2.26811447]
# 			 mean_minus_1sd : [0.2452816]
# 		 3.8
# 			 mean : [1.11981162]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [3.40521838]
# 			 mean_minus_1sd : [0.36825188]
# 		 4.0
# 			 mean : [1.68122163]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [5.11240168]
# 			 mean_minus_1sd : [0.55287247]
# 		 4.2
# 			 mean : [2.52409077]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [7.67546982]
# 			 mean_minus_1sd : [0.83005137]
# 		 4.4
# 			 mean : [3.78952668]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [11.52351492]
# 			 mean_minus_1sd : [1.24619203]
# 		 4.6
# 			 mean : [5.68938035]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [17.30075152]
# 			 mean_minus_1sd : [1.87096201]
# 		 4.8
# 			 mean : [8.54171287]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [25.97436676]
# 			 mean_minus_1sd : [2.80895621]
# 		 5.0
# 			 mean : [12.82404309]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [38.99644059]
# 			 mean_minus_1sd : [4.21720748]
# 		 5.2
# 			 mean : [19.25329072]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [58.54704344]
# 			 mean_minus_1sd : [6.33147605]
# 		 5.4
# 			 mean : [28.90579834]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [87.89920933]
# 			 mean_minus_1sd : [9.50571893]
# 		 5.6
# 			 mean : [43.39752565]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [131.96688591]
# 			 mean_minus_1sd : [14.27134709]
# 		 5.8
# 			 mean : [65.15458285]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [198.12759533]
# 			 mean_minus_1sd : [21.42619083]
# 		 6.0
# 			 mean : [97.81939412]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [297.45753081]
# 			 mean_minus_1sd : [32.16806729]
# 	 750
# 		 3.0
# 			 mean : [0.11763764]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [0.35772255]
# 			 mean_minus_1sd : [0.03868533]
# 		 3.2
# 			 mean : [0.17661448]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [0.53706433]
# 			 mean_minus_1sd : [0.05807996]
# 		 3.4
# 			 mean : [0.26515896]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [0.80631792]
# 			 mean_minus_1sd : [0.08719796]
# 		 3.6
# 			 mean : [0.39809462]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [1.21055998]
# 			 mean_minus_1sd : [0.13091407]
# 		 3.8
# 			 mean : [0.59767668]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [1.81746607]
# 			 mean_minus_1sd : [0.19654695]
# 		 4.0
# 			 mean : [0.89731786]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [2.72864045]
# 			 mean_minus_1sd : [0.29508444]
# 		 4.2
# 			 mean : [1.34718213]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [4.09662596]
# 			 mean_minus_1sd : [0.44302304]
# 		 4.4
# 			 mean : [2.02258281]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [6.15044179]
# 			 mean_minus_1sd : [0.66512966]
# 		 4.6
# 			 mean : [3.03659108]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [9.23392436]
# 			 mean_minus_1sd : [0.99858793]
# 		 4.8
# 			 mean : [4.55896557]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [13.86329014]
# 			 mean_minus_1sd : [1.49922326]
# 		 5.0
# 			 mean : [6.84457226]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [20.81355728]
# 			 mean_minus_1sd : [2.25084875]
# 		 5.2
# 			 mean : [10.27605246]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [31.24829404]
# 			 mean_minus_1sd : [3.37929661]
# 		 5.4
# 			 mean : [15.42788214]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [46.91441579]
# 			 mean_minus_1sd : [5.0734842]
# 		 5.6
# 			 mean : [23.16254694]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [70.43464216]
# 			 mean_minus_1sd : [7.61704134]
# 		 5.8
# 			 mean : [34.77493385]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [105.74657561]
# 			 mean_minus_1sd : [11.43579371]
# 		 6.0
# 			 mean : [52.20911272]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [158.76190906]
# 			 mean_minus_1sd : [17.16905186]
# 	 1000
# 		 3.0
# 			 mean : [0.07365111]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [0.22396457]
# 			 mean_minus_1sd : [0.02422029]
# 		 3.2
# 			 mean : [0.11057561]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [0.3362477]
# 			 mean_minus_1sd : [0.03636297]
# 		 3.4
# 			 mean : [0.16601194]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [0.50482322]
# 			 mean_minus_1sd : [0.0545933]
# 		 3.6
# 			 mean : [0.24924091]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [0.75791294]
# 			 mean_minus_1sd : [0.08196328]
# 		 3.8
# 			 mean : [0.37419616]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [1.13788749]
# 			 mean_minus_1sd : [0.12305502]
# 		 4.0
# 			 mean : [0.56179688]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [1.70835973]
# 			 mean_minus_1sd : [0.18474782]
# 		 4.2
# 			 mean : [0.84344996]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [2.56483437]
# 			 mean_minus_1sd : [0.2773699]
# 		 4.4
# 			 mean : [1.26630792]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [3.8506968]
# 			 mean_minus_1sd : [0.41642743]
# 		 4.6
# 			 mean : [1.90116287]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [5.78121771]
# 			 mean_minus_1sd : [0.62520051]
# 		 4.8
# 			 mean : [2.85429807]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [8.67959227]
# 			 mean_minus_1sd : [0.93864058]
# 		 5.0
# 			 mean : [4.28528119]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [13.0310474]
# 			 mean_minus_1sd : [1.40922171]
# 		 5.2
# 			 mean : [6.43367805]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [19.56407524]
# 			 mean_minus_1sd : [2.11572552]
# 		 5.4
# 			 mean : [9.65915921]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [29.3723926]
# 			 mean_minus_1sd : [3.17643026]
# 		 5.6
# 			 mean : [14.50171362]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [44.09804379]
# 			 mean_minus_1sd : [4.76891217]
# 		 5.8
# 			 mean : [21.77205007]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [66.20630104]
# 			 mean_minus_1sd : [7.15977417]
# 		 6.0
# 			 mean : [32.68732073]
# 			 stddevs : [1.1121486]
# 			 mean_plus_1sd : [99.39838415]
# 			 mean_minus_1sd : [10.74927873]
# Atkinson2015
# 	 300
# 		 3.0
# 			 mean : [0.10375134]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.24321688]
# 			 mean_minus_1sd : [0.0442582]
# 		 3.2
# 			 mean : [0.17243353]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.40422364]
# 			 mean_minus_1sd : [0.07355661]
# 		 3.4
# 			 mean : [0.28055997]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.65769677]
# 			 mean_minus_1sd : [0.11968114]
# 		 3.6
# 			 mean : [0.44689522]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [1.04762466]
# 			 mean_minus_1sd : [0.19063635]
# 		 3.8
# 			 mean : [0.69688596]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [1.63366014]
# 			 mean_minus_1sd : [0.29727728]
# 		 4.0
# 			 mean : [1.06388262]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.49398428]
# 			 mean_minus_1sd : [0.45383053]
# 		 4.2
# 			 mean : [1.15118101]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.6986317]
# 			 mean_minus_1sd : [0.49107024]
# 		 4.4
# 			 mean : [1.21039723]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.83744805]
# 			 mean_minus_1sd : [0.51633067]
# 		 4.6
# 			 mean : [1.23942419]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.90549391]
# 			 mean_minus_1sd : [0.52871298]
# 		 4.8
# 			 mean : [1.23799882]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.9021525]
# 			 mean_minus_1sd : [0.52810494]
# 		 5.0
# 			 mean : [1.20759703]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.83088376]
# 			 mean_minus_1sd : [0.51513616]
# 		 5.2
# 			 mean : [1.15124508]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.69878189]
# 			 mean_minus_1sd : [0.49109757]
# 		 5.4
# 			 mean : [1.07322986]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.51589636]
# 			 mean_minus_1sd : [0.45781788]
# 		 5.6
# 			 mean : [0.9787178]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.29433847]
# 			 mean_minus_1sd : [0.41750097]
# 		 5.8
# 			 mean : [0.87331535]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.04725102]
# 			 mean_minus_1sd : [0.37253844]
# 		 6.0
# 			 mean : [0.76261871]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [1.78775276]
# 			 mean_minus_1sd : [0.32531752]
# 	 500
# 		 3.0
# 			 mean : [0.09202083]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.21571788]
# 			 mean_minus_1sd : [0.0392542]
# 		 3.2
# 			 mean : [0.15293756]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.35852063]
# 			 mean_minus_1sd : [0.06524003]
# 		 3.4
# 			 mean : [0.24883883]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.58333516]
# 			 mean_minus_1sd : [0.10614955]
# 		 3.6
# 			 mean : [0.39636761]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.92917636]
# 			 mean_minus_1sd : [0.1690823]
# 		 3.8
# 			 mean : [0.61809347]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [1.44895252]
# 			 mean_minus_1sd : [0.26366601]
# 		 4.0
# 			 mean : [0.94359613]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.21200525]
# 			 mean_minus_1sd : [0.40251878]
# 		 4.2
# 			 mean : [1.05768385]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.47945296]
# 			 mean_minus_1sd : [0.45118627]
# 		 4.4
# 			 mean : [1.14109254]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.67498201]
# 			 mean_minus_1sd : [0.48676671]
# 		 4.6
# 			 mean : [1.19008504]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.78983164]
# 			 mean_minus_1sd : [0.5076659]
# 		 4.8
# 			 mean : [1.20407724]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.82263256]
# 			 mean_minus_1sd : [0.51363469]
# 		 5.0
# 			 mean : [1.18498234]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.77786975]
# 			 mean_minus_1sd : [0.5054892]
# 		 5.2
# 			 mean : [1.13658237]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.66440915]
# 			 mean_minus_1sd : [0.48484276]
# 		 5.4
# 			 mean : [1.06396481]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.49417697]
# 			 mean_minus_1sd : [0.4538656]
# 		 5.6
# 			 mean : [0.9730041]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.28094425]
# 			 mean_minus_1sd : [0.41506362]
# 		 5.8
# 			 mean : [0.86987302]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.03918139]
# 			 mean_minus_1sd : [0.37107001]
# 		 6.0
# 			 mean : [0.76059127]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [1.78299996]
# 			 mean_minus_1sd : [0.32445266]
# 	 750
# 		 3.0
# 			 mean : [0.07568207]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.17741608]
# 			 mean_minus_1sd : [0.03228442]
# 		 3.2
# 			 mean : [0.12578272]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.29486348]
# 			 mean_minus_1sd : [0.05365633]
# 		 3.4
# 			 mean : [0.20465624]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.47976104]
# 			 mean_minus_1sd : [0.08730216]
# 		 3.6
# 			 mean : [0.32599053]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.76419639]
# 			 mean_minus_1sd : [0.13906088]
# 		 3.8
# 			 mean : [0.50834784]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [1.19168365]
# 			 mean_minus_1sd : [0.21685078]
# 		 4.0
# 			 mean : [0.77605586]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [1.81925251]
# 			 mean_minus_1sd : [0.33104953]
# 		 4.2
# 			 mean : [0.91491631]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.14477317]
# 			 mean_minus_1sd : [0.39028456]
# 		 4.4
# 			 mean : [1.02751869]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.40873893]
# 			 mean_minus_1sd : [0.43831843]
# 		 4.6
# 			 mean : [1.1048803]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.59009225]
# 			 mean_minus_1sd : [0.47131931]
# 		 4.8
# 			 mean : [1.14324058]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.68001751]
# 			 mean_minus_1sd : [0.48768302]
# 		 5.0
# 			 mean : [1.14332586]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.68021742]
# 			 mean_minus_1sd : [0.48771939]
# 		 5.2
# 			 mean : [1.10906643]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.59990549]
# 			 mean_minus_1sd : [0.47310503]
# 		 5.4
# 			 mean : [1.04635385]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.45289286]
# 			 mean_minus_1sd : [0.44635312]
# 		 5.6
# 			 mean : [0.96204795]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.25526053]
# 			 mean_minus_1sd : [0.41038995]
# 		 5.8
# 			 mean : [0.86323279]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.02361518]
# 			 mean_minus_1sd : [0.36823743]
# 		 6.0
# 			 mean : [0.75666451]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [1.77379474]
# 			 mean_minus_1sd : [0.32277758]
# 	 1000
# 		 3.0
# 			 mean : [0.0609645]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.14291475]
# 			 mean_minus_1sd : [0.02600621]
# 		 3.2
# 			 mean : [0.1013223]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.23752266]
# 			 mean_minus_1sd : [0.04322202]
# 		 3.4
# 			 mean : [0.16485763]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.386464]
# 			 mean_minus_1sd : [0.07032489]
# 		 3.6
# 			 mean : [0.26259657]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.61558644]
# 			 mean_minus_1sd : [0.11201832]
# 		 3.8
# 			 mean : [0.40949165]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [0.95994212]
# 			 mean_minus_1sd : [0.17468075]
# 		 4.0
# 			 mean : [0.62513965]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [1.46547039]
# 			 mean_minus_1sd : [0.26667177]
# 		 4.2
# 			 mean : [0.77221492]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [1.81024847]
# 			 mean_minus_1sd : [0.32941107]
# 		 4.4
# 			 mean : [0.90366917]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.1184073]
# 			 mean_minus_1sd : [0.38548676]
# 		 4.6
# 			 mean : [1.00531436]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.3566869]
# 			 mean_minus_1sd : [0.42884652]
# 		 4.8
# 			 mean : [1.06831169]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.50436705]
# 			 mean_minus_1sd : [0.45571989]
# 		 5.0
# 			 mean : [1.08999839]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.55520564]
# 			 mean_minus_1sd : [0.46497099]
# 		 5.2
# 			 mean : [1.07285256]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.51501188]
# 			 mean_minus_1sd : [0.45765693]
# 		 5.4
# 			 mean : [1.02272057]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.39749103]
# 			 mean_minus_1sd : [0.43627165]
# 		 5.6
# 			 mean : [0.94714544]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.22032564]
# 			 mean_minus_1sd : [0.40403285]
# 		 5.8
# 			 mean : [0.85411667]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [2.00224491]
# 			 mean_minus_1sd : [0.36434868]
# 		 6.0
# 			 mean : [0.75123939]
# 			 stddevs : [0.85195648]
# 			 mean_plus_1sd : [1.76107703]
# 			 mean_minus_1sd : [0.32046334]
# ZalachorisRathje2019
# 	 300
# 		 3.0
# 			 mean : [0.0366577]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.06810997]
# 			 mean_minus_1sd : [0.01972967]
# 		 3.2
# 			 mean : [0.04925374]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.09151339]
# 			 mean_minus_1sd : [0.02650903]
# 		 3.4
# 			 mean : [0.06629637]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.12317858]
# 			 mean_minus_1sd : [0.0356816]
# 		 3.6
# 			 mean : [0.08420353]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.15645006]
# 			 mean_minus_1sd : [0.04531948]
# 		 3.8
# 			 mean : [0.1073805]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.19951284]
# 			 mean_minus_1sd : [0.05779363]
# 		 4.0
# 			 mean : [0.13749125]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.25545859]
# 			 mean_minus_1sd : [0.07399965]
# 		 4.2
# 			 mean : [0.17675808]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.3284163]
# 			 mean_minus_1sd : [0.09513358]
# 		 4.4
# 			 mean : [0.22815922]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.42391957]
# 			 mean_minus_1sd : [0.12279837]
# 		 4.6
# 			 mean : [0.29570001]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.54941026]
# 			 mean_minus_1sd : [0.15914973]
# 		 4.8
# 			 mean : [0.38478594]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.71493181]
# 			 mean_minus_1sd : [0.20709698]
# 		 5.0
# 			 mean : [0.50273786]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.93408635]
# 			 mean_minus_1sd : [0.27058029]
# 		 5.2
# 			 mean : [0.65950569]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.22536079]
# 			 mean_minus_1sd : [0.35495485]
# 		 5.4
# 			 mean : [0.86866046]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.6139701]
# 			 mean_minus_1sd : [0.46752476]
# 		 5.6
# 			 mean : [0.97882125]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.81864871]
# 			 mean_minus_1sd : [0.52681479]
# 		 5.8
# 			 mean : [0.9407249]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.74786575]
# 			 mean_minus_1sd : [0.50631082]
# 		 6.0
# 			 mean : [0.96419395]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.79147122]
# 			 mean_minus_1sd : [0.51894218]
# 	 500
# 		 3.0
# 			 mean : [0.03647795]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.06777598]
# 			 mean_minus_1sd : [0.01963292]
# 		 3.2
# 			 mean : [0.04901959]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.09107835]
# 			 mean_minus_1sd : [0.02638301]
# 		 3.4
# 			 mean : [0.06599113]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.12261144]
# 			 mean_minus_1sd : [0.03551732]
# 		 3.6
# 			 mean : [0.08382845]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.15575317]
# 			 mean_minus_1sd : [0.0451176]
# 		 3.8
# 			 mean : [0.10691826]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.19865401]
# 			 mean_minus_1sd : [0.05754485]
# 		 4.0
# 			 mean : [0.13692]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.25439719]
# 			 mean_minus_1sd : [0.07369219]
# 		 4.2
# 			 mean : [0.17605016]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.32710099]
# 			 mean_minus_1sd : [0.09475257]
# 		 4.4
# 			 mean : [0.22727963]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.42228529]
# 			 mean_minus_1sd : [0.12232496]
# 		 4.6
# 			 mean : [0.29460435]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.54737454]
# 			 mean_minus_1sd : [0.15856003]
# 		 4.8
# 			 mean : [0.38341787]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.71238994]
# 			 mean_minus_1sd : [0.20636066]
# 		 5.0
# 			 mean : [0.5010258]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.93090534]
# 			 mean_minus_1sd : [0.26965884]
# 		 5.2
# 			 mean : [0.65735864]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.22137158]
# 			 mean_minus_1sd : [0.35379928]
# 		 5.4
# 			 mean : [0.86596276]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.60895778]
# 			 mean_minus_1sd : [0.46607283]
# 		 5.6
# 			 mean : [0.97592825]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.81327352]
# 			 mean_minus_1sd : [0.52525774]
# 		 5.8
# 			 mean : [0.93808562]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.74296197]
# 			 mean_minus_1sd : [0.50489032]
# 		 6.0
# 			 mean : [0.96163348]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.78671387]
# 			 mean_minus_1sd : [0.5175641]
# 	 750
# 		 3.0
# 			 mean : [0.03611405]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.06709986]
# 			 mean_minus_1sd : [0.01943707]
# 		 3.2
# 			 mean : [0.04854468]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.09019596]
# 			 mean_minus_1sd : [0.0261274]
# 		 3.4
# 			 mean : [0.06537078]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.12145883]
# 			 mean_minus_1sd : [0.03518343]
# 		 3.6
# 			 mean : [0.08306455]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.15433383]
# 			 mean_minus_1sd : [0.04470646]
# 		 3.8
# 			 mean : [0.10597473]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.19690092]
# 			 mean_minus_1sd : [0.05703703]
# 		 4.0
# 			 mean : [0.13575113]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.25222543]
# 			 mean_minus_1sd : [0.07306309]
# 		 4.2
# 			 mean : [0.17459795]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.32440278]
# 			 mean_minus_1sd : [0.09397097]
# 		 4.4
# 			 mean : [0.22547032]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.41892359]
# 			 mean_minus_1sd : [0.12135117]
# 		 4.6
# 			 mean : [0.29234399]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.54317479]
# 			 mean_minus_1sd : [0.15734348]
# 		 4.8
# 			 mean : [0.38058662]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.70712949]
# 			 mean_minus_1sd : [0.20483685]
# 		 5.0
# 			 mean : [0.49747059]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.92429976]
# 			 mean_minus_1sd : [0.26774537]
# 		 5.2
# 			 mean : [0.65288373]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.2130572]
# 			 mean_minus_1sd : [0.35139082]
# 		 5.4
# 			 mean : [0.86031766]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.59846919]
# 			 mean_minus_1sd : [0.46303456]
# 		 5.6
# 			 mean : [0.96984797]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.80197638]
# 			 mean_minus_1sd : [0.52198525]
# 		 5.8
# 			 mean : [0.93251194]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.73260608]
# 			 mean_minus_1sd : [0.5018905]
# 		 6.0
# 			 mean : [0.95619761]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.77661401]
# 			 mean_minus_1sd : [0.51463844]
# 	 1000
# 		 3.0
# 			 mean : [0.0356064]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.06615664]
# 			 mean_minus_1sd : [0.01916384]
# 		 3.2
# 			 mean : [0.04788141]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.0889636]
# 			 mean_minus_1sd : [0.02577042]
# 		 3.4
# 			 mean : [0.06450337]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.11984719]
# 			 mean_minus_1sd : [0.03471658]
# 		 3.6
# 			 mean : [0.0819951]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.15234681]
# 			 mean_minus_1sd : [0.04413087]
# 		 3.8
# 			 mean : [0.10465211]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.19444349]
# 			 mean_minus_1sd : [0.05632518]
# 		 4.0
# 			 mean : [0.13411044]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.24917704]
# 			 mean_minus_1sd : [0.07218005]
# 		 4.2
# 			 mean : [0.17255667]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.32061009]
# 			 mean_minus_1sd : [0.09287233]
# 		 4.4
# 			 mean : [0.2229233]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.41419122]
# 			 mean_minus_1sd : [0.11998032]
# 		 4.6
# 			 mean : [0.28915701]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.53725337]
# 			 mean_minus_1sd : [0.1556282]
# 		 4.8
# 			 mean : [0.37658804]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.69970013]
# 			 mean_minus_1sd : [0.20268476]
# 		 5.0
# 			 mean : [0.49244064]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [0.91495412]
# 			 mean_minus_1sd : [0.26503819]
# 		 5.2
# 			 mean : [0.64654058]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.20127163]
# 			 mean_minus_1sd : [0.34797686]
# 		 5.4
# 			 mean : [0.85229953]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.58357151]
# 			 mean_minus_1sd : [0.45871909]
# 		 5.6
# 			 mean : [0.96119286]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.78589519]
# 			 mean_minus_1sd : [0.51732695]
# 		 5.8
# 			 mean : [0.92455924]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.71782997]
# 			 mean_minus_1sd : [0.49761024]
# 		 6.0
# 			 mean : [0.94842165]
# 			 stddevs : [0.6195]
# 			 mean_plus_1sd : [1.76216629]
# 			 mean_minus_1sd : [0.51045331]
# DostEtAl2004
# 	 300
# 		 3.0
# 			 mean : [1.00807085]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [2.15521726]
# 			 mean_minus_1sd : [0.47151016]
# 		 3.2
# 			 mean : [1.31066305]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [2.80214791]
# 			 mean_minus_1sd : [0.61304317]
# 		 3.4
# 			 mean : [1.70408422]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [3.64326747]
# 			 mean_minus_1sd : [0.79706007]
# 		 3.6
# 			 mean : [2.21559847]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [4.73686552]
# 			 mean_minus_1sd : [1.03631326]
# 		 3.8
# 			 mean : [2.88065372]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [6.15872845]
# 			 mean_minus_1sd : [1.34738298]
# 		 4.0
# 			 mean : [3.74533833]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [8.00739137]
# 			 mean_minus_1sd : [1.75182635]
# 		 4.2
# 			 mean : [4.86957496]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [10.41096666]
# 			 mean_minus_1sd : [2.27767133]
# 		 4.4
# 			 mean : [6.33127322]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [13.53602213]
# 			 mean_minus_1sd : [2.96135898]
# 		 4.6
# 			 mean : [8.23172883]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [17.59912418]
# 			 mean_minus_1sd : [3.85026885]
# 		 4.8
# 			 mean : [10.7026434]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [22.88184586]
# 			 mean_minus_1sd : [5.00600242]
# 		 5.0
# 			 mean : [13.91525136]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [29.75027987]
# 			 mean_minus_1sd : [6.50865206]
# 		 5.2
# 			 mean : [18.09218649]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [38.68040883]
# 			 mean_minus_1sd : [8.4623514]
# 		 5.4
# 			 mean : [23.52291047]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [50.29109082]
# 			 mean_minus_1sd : [11.00249185]
# 		 5.6
# 			 mean : [30.58377258]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [65.38694633]
# 			 mean_minus_1sd : [14.30510519]
# 		 5.8
# 			 mean : [39.76409069]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [85.01411842]
# 			 mean_minus_1sd : [18.59906258]
# 		 6.0
# 			 mean : [51.70006102]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [110.53277048]
# 			 mean_minus_1sd : [24.18193534]
# 	 500
# 		 3.0
# 			 mean : [0.51068631]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [1.09182798]
# 			 mean_minus_1sd : [0.23886593]
# 		 3.2
# 			 mean : [0.66397881]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [1.41956152]
# 			 mean_minus_1sd : [0.31056622]
# 		 3.4
# 			 mean : [0.86328505]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [1.8456707]
# 			 mean_minus_1sd : [0.40378875]
# 		 3.6
# 			 mean : [1.12241696]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [2.3996849]
# 			 mean_minus_1sd : [0.52499385]
# 		 3.8
# 			 mean : [1.45933238]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [3.1199973]
# 			 mean_minus_1sd : [0.68258104]
# 		 4.0
# 			 mean : [1.89737956]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [4.05652558]
# 			 mean_minus_1sd : [0.8874711]
# 		 4.2
# 			 mean : [2.46691519]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [5.27417115]
# 			 mean_minus_1sd : [1.15386292]
# 		 4.4
# 			 mean : [3.20740808]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [6.85731688]
# 			 mean_minus_1sd : [1.50021747]
# 		 4.6
# 			 mean : [4.17017441]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [8.91567479]
# 			 mean_minus_1sd : [1.95053712]
# 		 4.8
# 			 mean : [5.4219339]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [11.59188913]
# 			 mean_minus_1sd : [2.53602902]
# 		 5.0
# 			 mean : [7.04943351]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [15.0714216]
# 			 mean_minus_1sd : [3.29726778]
# 		 5.2
# 			 mean : [9.16545899]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [19.59540386]
# 			 mean_minus_1sd : [4.28700726]
# 		 5.4
# 			 mean : [11.91665095]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [25.47734797]
# 			 mean_minus_1sd : [5.57383642]
# 		 5.6
# 			 mean : [15.49366704]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [33.12487275]
# 			 mean_minus_1sd : [7.24693254]
# 		 5.8
# 			 mean : [20.14439453]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [43.06795183]
# 			 mean_minus_1sd : [9.42224122]
# 		 6.0
# 			 mean : [26.19112894]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [55.99564076]
# 			 mean_minus_1sd : [12.2505114]
# 	 750
# 		 3.0
# 			 mean : [0.2975811]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [0.63621711]
# 			 mean_minus_1sd : [0.13918914]
# 		 3.2
# 			 mean : [0.38690589]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [0.82719013]
# 			 mean_minus_1sd : [0.18096948]
# 		 3.4
# 			 mean : [0.50304327]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [1.07548744]
# 			 mean_minus_1sd : [0.23529102]
# 		 3.6
# 			 mean : [0.65404156]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [1.39831606]
# 			 mean_minus_1sd : [0.30591822]
# 		 3.8
# 			 mean : [0.85036494]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [1.818048]
# 			 mean_minus_1sd : [0.39774556]
# 		 4.0
# 			 mean : [1.10561862]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [2.36377069]
# 			 mean_minus_1sd : [0.51713668]
# 		 4.2
# 			 mean : [1.43749169]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [3.07330275]
# 			 mean_minus_1sd : [0.67236538]
# 		 4.4
# 			 mean : [1.86898297]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [3.99581474]
# 			 mean_minus_1sd : [0.87418901]
# 		 4.6
# 			 mean : [2.4299948]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [5.19523676]
# 			 mean_minus_1sd : [1.13659396]
# 		 4.8
# 			 mean : [3.15940531]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [6.75468878]
# 			 mean_minus_1sd : [1.47776489]
# 		 5.0
# 			 mean : [4.10776267]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [8.78224087]
# 			 mean_minus_1sd : [1.92134495]
# 		 5.2
# 			 mean : [5.34078806]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [11.4184024]
# 			 mean_minus_1sd : [2.49807426]
# 		 5.4
# 			 mean : [6.94393016]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [14.84585943]
# 			 mean_minus_1sd : [3.24792015]
# 		 5.6
# 			 mean : [9.02828674]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [19.30213479]
# 			 mean_minus_1sd : [4.22284698]
# 		 5.8
# 			 mean : [11.73830377]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [25.09604845]
# 			 mean_minus_1sd : [5.49041717]
# 		 6.0
# 			 mean : [15.26178546]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [32.62911872]
# 			 mean_minus_1sd : [7.13847338]
# 	 1000
# 		 3.0
# 			 mean : [0.20280998]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [0.43360005]
# 			 mean_minus_1sd : [0.09486136]
# 		 3.2
# 			 mean : [0.26368737]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [0.5637536]
# 			 mean_minus_1sd : [0.12333585]
# 		 3.4
# 			 mean : [0.34283829]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [0.73297527]
# 			 mean_minus_1sd : [0.16035752]
# 		 3.6
# 			 mean : [0.44574792]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [0.95299215]
# 			 mean_minus_1sd : [0.20849197]
# 		 3.8
# 			 mean : [0.57954788]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [1.2390514]
# 			 mean_minus_1sd : [0.27107491]
# 		 4.0
# 			 mean : [0.75351053]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [1.61097694]
# 			 mean_minus_1sd : [0.35244335]
# 		 4.2
# 			 mean : [0.97969146]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [2.09454321]
# 			 mean_minus_1sd : [0.45823613]
# 		 4.4
# 			 mean : [1.27376504]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [2.72326136]
# 			 mean_minus_1sd : [0.59578467]
# 		 4.6
# 			 mean : [1.65611055]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [3.54070158]
# 			 mean_minus_1sd : [0.7746211]
# 		 4.8
# 			 mean : [2.15322456]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [4.60351248]
# 			 mean_minus_1sd : [1.00713879]
# 		 5.0
# 			 mean : [2.79955707]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [5.98534687]
# 			 mean_minus_1sd : [1.30945122]
# 		 5.2
# 			 mean : [3.63989893]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [7.78196592]
# 			 mean_minus_1sd : [1.70250864]
# 		 5.4
# 			 mean : [4.73248585]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [10.11787534]
# 			 mean_minus_1sd : [2.21354994]
# 		 5.6
# 			 mean : [6.15303414]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [13.15495372]
# 			 mean_minus_1sd : [2.87799029]
# 		 5.8
# 			 mean : [7.9999878]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [17.10367062]
# 			 mean_minus_1sd : [3.74187542]
# 		 6.0
# 			 mean : [10.40134076]
# 			 stddevs : [0.75985308]
# 			 mean_plus_1sd : [22.23767222]
# 			 mean_minus_1sd : [4.86507259]
# DouglasEtAl2013StochasticSD001Q200K005
# 	 300
# 		 3.0
# 			 mean : [0.17652976]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.46157629]
# 			 mean_minus_1sd : [0.06751377]
# 		 3.2
# 			 mean : [0.23164198]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.60567945]
# 			 mean_minus_1sd : [0.08859143]
# 		 3.4
# 			 mean : [0.29913245]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.78214828]
# 			 mean_minus_1sd : [0.11440315]
# 		 3.6
# 			 mean : [0.38074019]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.99552986]
# 			 mean_minus_1sd : [0.14561401]
# 		 3.8
# 			 mean : [0.47839309]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.25086506]
# 			 mean_minus_1sd : [0.18296134]
# 		 4.0
# 			 mean : [0.59429776]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.55392357]
# 			 mean_minus_1sd : [0.22728906]
# 		 4.2
# 			 mean : [0.73106894]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.91154224]
# 			 mean_minus_1sd : [0.27959717]
# 		 4.4
# 			 mean : [0.89190721]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [2.33208962]
# 			 mean_minus_1sd : [0.34110973]
# 		 4.6
# 			 mean : [1.08083684]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [2.82608815]
# 			 mean_minus_1sd : [0.41336583]
# 		 4.8
# 			 mean : [1.30302208]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [3.40704083]
# 			 mean_minus_1sd : [0.49834053]
# 		 5.0
# 			 mean : [1.56518838]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [4.09253289]
# 			 mean_minus_1sd : [0.59860598]
# 		 5.2
# 			 mean : [1.87618949]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [4.90571441]
# 			 mean_minus_1sd : [0.71754829]
# 		 5.4
# 			 mean : [2.24778134]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [5.8773239]
# 			 mean_minus_1sd : [0.85966352]
# 		 5.6
# 			 mean : [2.69569494]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [7.04849357]
# 			 mean_minus_1sd : [1.03096799]
# 		 5.8
# 			 mean : [3.2411474]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [8.47470025]
# 			 mean_minus_1sd : [1.23957617]
# 		 6.0
# 			 mean : [3.9130033]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [10.23141683]
# 			 mean_minus_1sd : [1.49652732]
# 	 500
# 		 3.0
# 			 mean : [0.09119156]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.23844061]
# 			 mean_minus_1sd : [0.0348762]
# 		 3.2
# 			 mean : [0.11966138]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.31288128]
# 			 mean_minus_1sd : [0.04576447]
# 		 3.4
# 			 mean : [0.15452554]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.40404137]
# 			 mean_minus_1sd : [0.05909826]
# 		 3.6
# 			 mean : [0.19668238]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.51426981]
# 			 mean_minus_1sd : [0.07522114]
# 		 3.8
# 			 mean : [0.24712782]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.64617061]
# 			 mean_minus_1sd : [0.09451399]
# 		 4.0
# 			 mean : [0.30700173]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.80272427]
# 			 mean_minus_1sd : [0.11741275]
# 		 4.2
# 			 mean : [0.37765486]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.98746256]
# 			 mean_minus_1sd : [0.14443402]
# 		 4.4
# 			 mean : [0.46074052]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.2047085]
# 			 mean_minus_1sd : [0.17621012]
# 		 4.6
# 			 mean : [0.5583376]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.45989776]
# 			 mean_minus_1sd : [0.2135361]
# 		 4.8
# 			 mean : [0.67311383]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.76000571]
# 			 mean_minus_1sd : [0.25743225]
# 		 5.0
# 			 mean : [0.80854343]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [2.11411651]
# 			 mean_minus_1sd : [0.30922727]
# 		 5.2
# 			 mean : [0.96920007]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [2.53418899]
# 			 mean_minus_1sd : [0.37067037]
# 		 5.4
# 			 mean : [1.16115662]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [3.03610205]
# 			 mean_minus_1sd : [0.44408411]
# 		 5.6
# 			 mean : [1.39253937]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [3.64110369]
# 			 mean_minus_1sd : [0.5325764]
# 		 5.8
# 			 mean : [1.67430865]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [4.37785209]
# 			 mean_minus_1sd : [0.64033901]
# 		 6.0
# 			 mean : [2.02137529]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [5.28533497]
# 			 mean_minus_1sd : [0.77307457]
# 	 750
# 		 3.0
# 			 mean : [0.05142452]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.13446083]
# 			 mean_minus_1sd : [0.0196673]
# 		 3.2
# 			 mean : [0.06747914]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.17643922]
# 			 mean_minus_1sd : [0.02580738]
# 		 3.4
# 			 mean : [0.08713965]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.22784598]
# 			 mean_minus_1sd : [0.03332654]
# 		 3.6
# 			 mean : [0.11091263]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.29000573]
# 			 mean_minus_1sd : [0.04241851]
# 		 3.8
# 			 mean : [0.13935969]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.36438689]
# 			 mean_minus_1sd : [0.05329809]
# 		 4.0
# 			 mean : [0.17312364]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.45267024]
# 			 mean_minus_1sd : [0.0662111]
# 		 4.2
# 			 mean : [0.21296617]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.55684738]
# 			 mean_minus_1sd : [0.08144887]
# 		 4.4
# 			 mean : [0.25981963]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.67935617]
# 			 mean_minus_1sd : [0.09936796]
# 		 4.6
# 			 mean : [0.31485633]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.82326185]
# 			 mean_minus_1sd : [0.12041674]
# 		 4.8
# 			 mean : [0.37958065]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.99249796]
# 			 mean_minus_1sd : [0.14517054]
# 		 5.0
# 			 mean : [0.45595176]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.19218722]
# 			 mean_minus_1sd : [0.17437866]
# 		 5.2
# 			 mean : [0.54654885]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.42907344]
# 			 mean_minus_1sd : [0.2090275]
# 		 5.4
# 			 mean : [0.6547965]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.71211097]
# 			 mean_minus_1sd : [0.25042679]
# 		 5.6
# 			 mean : [0.78527727]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [2.05328197]
# 			 mean_minus_1sd : [0.30032914]
# 		 5.8
# 			 mean : [0.94417189]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [2.46874726]
# 			 mean_minus_1sd : [0.36109835]
# 		 6.0
# 			 mean : [1.13988883]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [2.9804927]
# 			 mean_minus_1sd : [0.43595025]
# 	 1000
# 		 3.0
# 			 mean : [0.03354907]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.08772149]
# 			 mean_minus_1sd : [0.01283083]
# 		 3.2
# 			 mean : [0.04402302]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.11510796]
# 			 mean_minus_1sd : [0.01683659]
# 		 3.4
# 			 mean : [0.05684942]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.14864545]
# 			 mean_minus_1sd : [0.02174205]
# 		 3.6
# 			 mean : [0.07235878]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.18919812]
# 			 mean_minus_1sd : [0.0276736]
# 		 3.8
# 			 mean : [0.09091749]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.23772398]
# 			 mean_minus_1sd : [0.03477138]
# 		 4.0
# 			 mean : [0.1129449]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.29531954]
# 			 mean_minus_1sd : [0.04319575]
# 		 4.2
# 			 mean : [0.13893794]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.36328414]
# 			 mean_minus_1sd : [0.05313679]
# 		 4.4
# 			 mean : [0.16950488]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.44320818]
# 			 mean_minus_1sd : [0.06482711]
# 		 4.6
# 			 mean : [0.20541052]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.53709145]
# 			 mean_minus_1sd : [0.07855921]
# 		 4.8
# 			 mean : [0.2476363]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.64750015]
# 			 mean_minus_1sd : [0.09470845]
# 		 5.0
# 			 mean : [0.29746039]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.77777631]
# 			 mean_minus_1sd : [0.11376367]
# 		 5.2
# 			 mean : [0.35656543]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [0.93231956]
# 			 mean_minus_1sd : [0.13636838]
# 		 5.4
# 			 mean : [0.42718559]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.11697167]
# 			 mean_minus_1sd : [0.16337704]
# 		 5.6
# 			 mean : [0.51231052]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.33954973]
# 			 mean_minus_1sd : [0.19593306]
# 		 5.8
# 			 mean : [0.61597249]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.61059698]
# 			 mean_minus_1sd : [0.23557855]
# 		 6.0
# 			 mean : [0.74365713]
# 			 stddevs : [0.96115788]
# 			 mean_plus_1sd : [1.94445686]
# 			 mean_minus_1sd : [0.28441152]
# Allen2012
# 	 300
# 		 3.0
# 			 mean : [3.2549778]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [8.4051996]
# 			 mean_minus_1sd : [1.26051504]
# 		 3.2
# 			 mean : [7.01179135]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [18.10626966]
# 			 mean_minus_1sd : [2.7153698]
# 		 3.4
# 			 mean : [5.3163587]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [13.72822142]
# 			 mean_minus_1sd : [2.05880055]
# 		 3.6
# 			 mean : [3.14555438]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [8.12263984]
# 			 mean_minus_1sd : [1.21813998]
# 		 3.8
# 			 mean : [2.16759657]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [5.59729834]
# 			 mean_minus_1sd : [0.83941834]
# 		 4.0
# 			 mean : [1.70872882]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [4.41238241]
# 			 mean_minus_1sd : [0.6617183]
# 		 4.2
# 			 mean : [1.47468842]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.8080292]
# 			 mean_minus_1sd : [0.57108436]
# 		 4.4
# 			 mean : [1.35229326]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.49197305]
# 			 mean_minus_1sd : [0.5236859]
# 		 4.6
# 			 mean : [1.29256394]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.33773642]
# 			 mean_minus_1sd : [0.50055527]
# 		 4.8
# 			 mean : [1.27157121]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.28352771]
# 			 mean_minus_1sd : [0.49242567]
# 		 5.0
# 			 mean : [1.27630669]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.29575597]
# 			 mean_minus_1sd : [0.49425952]
# 		 5.2
# 			 mean : [1.29896609]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.35426842]
# 			 mean_minus_1sd : [0.50303455]
# 		 5.4
# 			 mean : [1.33438798]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.44573696]
# 			 mean_minus_1sd : [0.51675195]
# 		 5.6
# 			 mean : [1.3788074]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.56043947]
# 			 mean_minus_1sd : [0.53395371]
# 		 5.8
# 			 mean : [1.42921051]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.69059339]
# 			 mean_minus_1sd : [0.55347269]
# 		 6.0
# 			 mean : [1.48298812]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.8294612]
# 			 mean_minus_1sd : [0.57429849]
# 	 500
# 		 3.0
# 			 mean : [1.5813187]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [4.08337633]
# 			 mean_minus_1sd : [0.61237776]
# 		 3.2
# 			 mean : [2.56991429]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [6.63618735]
# 			 mean_minus_1sd : [0.99521895]
# 		 3.4
# 			 mean : [2.66591399]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [6.88408357]
# 			 mean_minus_1sd : [1.03239557]
# 		 3.6
# 			 mean : [2.18251616]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [5.6358246]
# 			 mean_minus_1sd : [0.84519607]
# 		 3.8
# 			 mean : [1.76620763]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [4.56080766]
# 			 mean_minus_1sd : [0.68397741]
# 		 4.0
# 			 mean : [1.5065722]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.89036142]
# 			 mean_minus_1sd : [0.5834316]
# 		 4.2
# 			 mean : [1.35644204]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.50268627]
# 			 mean_minus_1sd : [0.52529255]
# 		 4.4
# 			 mean : [1.27505636]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.29252727]
# 			 mean_minus_1sd : [0.49377532]
# 		 4.6
# 			 mean : [1.23783855]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.19642122]
# 			 mean_minus_1sd : [0.47936244]
# 		 4.8
# 			 mean : [1.23037058]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.17713698]
# 			 mean_minus_1sd : [0.47647042]
# 		 5.0
# 			 mean : [1.24383383]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.21190257]
# 			 mean_minus_1sd : [0.48168416]
# 		 5.2
# 			 mean : [1.27246228]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.28582868]
# 			 mean_minus_1sd : [0.49277074]
# 		 5.4
# 			 mean : [1.31216942]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.38836286]
# 			 mean_minus_1sd : [0.50814764]
# 		 5.6
# 			 mean : [1.35979577]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.51134648]
# 			 mean_minus_1sd : [0.52659131]
# 		 5.8
# 			 mean : [1.41268751]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.64792671]
# 			 mean_minus_1sd : [0.54707404]
# 		 6.0
# 			 mean : [1.46845939]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.79194422]
# 			 mean_minus_1sd : [0.56867212]
# 	 750
# 		 3.0
# 			 mean : [0.78945093]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.03856771]
# 			 mean_minus_1sd : [0.30572091]
# 		 3.2
# 			 mean : [1.15852745]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.99161932]
# 			 mean_minus_1sd : [0.44864861]
# 		 3.4
# 			 mean : [1.36623911]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.52798486]
# 			 mean_minus_1sd : [0.52908654]
# 		 3.6
# 			 mean : [1.37685648]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.55540167]
# 			 mean_minus_1sd : [0.5331982]
# 		 3.8
# 			 mean : [1.30324598]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.36532022]
# 			 mean_minus_1sd : [0.50469197]
# 		 4.0
# 			 mean : [1.22715826]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.16884192]
# 			 mean_minus_1sd : [0.47522642]
# 		 4.2
# 			 mean : [1.17471489]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.03341951]
# 			 mean_minus_1sd : [0.45491732]
# 		 4.4
# 			 mean : [1.14828926]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.96518164]
# 			 mean_minus_1sd : [0.44468379]
# 		 4.6
# 			 mean : [1.14408108]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.95431502]
# 			 mean_minus_1sd : [0.44305414]
# 		 4.8
# 			 mean : [1.15768608]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.98944667]
# 			 mean_minus_1sd : [0.44832278]
# 		 5.0
# 			 mean : [1.18534452]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.06086796]
# 			 mean_minus_1sd : [0.45903373]
# 		 5.2
# 			 mean : [1.22399344]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.16066953]
# 			 mean_minus_1sd : [0.47400082]
# 		 5.4
# 			 mean : [1.27107061]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.28223502]
# 			 mean_minus_1sd : [0.49223181]
# 		 5.6
# 			 mean : [1.32431883]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.41973578]
# 			 mean_minus_1sd : [0.51285259]
# 		 5.8
# 			 mean : [1.38164152]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.56775789]
# 			 mean_minus_1sd : [0.53505124]
# 		 6.0
# 			 mean : [1.44101024]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.72106338]
# 			 mean_minus_1sd : [0.55804223]
# 	 1000
# 		 3.0
# 			 mean : [0.46428501]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [1.19890471]
# 			 mean_minus_1sd : [0.17979792]
# 		 3.2
# 			 mean : [0.65827016]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [1.69982482]
# 			 mean_minus_1sd : [0.25492015]
# 		 3.4
# 			 mean : [0.81853009]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.11365767]
# 			 mean_minus_1sd : [0.31698204]
# 		 3.6
# 			 mean : [0.9145973]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.3617282]
# 			 mean_minus_1sd : [0.3541848]
# 		 3.8
# 			 mean : [0.95878466]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.47583146]
# 			 mean_minus_1sd : [0.37129669]
# 		 4.0
# 			 mean : [0.97800809]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.52547137]
# 			 mean_minus_1sd : [0.37874111]
# 		 4.2
# 			 mean : [0.99179027]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.56106053]
# 			 mean_minus_1sd : [0.38407836]
# 		 4.4
# 			 mean : [1.0098027]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.60757332]
# 			 mean_minus_1sd : [0.39105382]
# 		 4.6
# 			 mean : [1.03569073]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.67442295]
# 			 mean_minus_1sd : [0.40107915]
# 		 4.8
# 			 mean : [1.07020868]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.76355727]
# 			 mean_minus_1sd : [0.41444649]
# 		 5.0
# 			 mean : [1.11285485]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [2.87368077]
# 			 mean_minus_1sd : [0.43096155]
# 		 5.2
# 			 mean : [1.16259054]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.00211127]
# 			 mean_minus_1sd : [0.45022207]
# 		 5.4
# 			 mean : [1.21812481]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.1455152]
# 			 mean_minus_1sd : [0.47172814]
# 		 5.6
# 			 mean : [1.27801545]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.30016843]
# 			 mean_minus_1sd : [0.49492126]
# 		 5.8
# 			 mean : [1.34070068]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.462038]
# 			 mean_minus_1sd : [0.51919659]
# 		 6.0
# 			 mean : [1.40451093]
# 			 stddevs : [0.94866506]
# 			 mean_plus_1sd : [3.62681267]
# 			 mean_minus_1sd : [0.5439076]
# AtkinsonBoore2006
# 	 300
# ...
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.01488602]
# 			 mean_minus_1sd : [0.00300007]
# 		 3.2
# 			 mean : [0.00897975]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.02000265]
# 			 mean_minus_1sd : [0.00403126]
# 		 3.4
# 			 mean : [0.01211516]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.02698685]
# 			 mean_minus_1sd : [0.00543883]
# 		 3.6
# 			 mean : [0.01641154]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.03655717]
# 			 mean_minus_1sd : [0.0073676]
# 		 3.8
# 			 mean : [0.02232159]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.04972197]
# 			 mean_minus_1sd : [0.01002079]
# 		 4.0
# 			 mean : [0.03048292]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.06790157]
# 			 mean_minus_1sd : [0.01368464]
# 		 4.2
# 			 mean : [0.04179685]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.09310367]
# 			 mean_minus_1sd : [0.01876378]
# 		 4.4
# 			 mean : [0.05754216]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.1281768]
# 			 mean_minus_1sd : [0.02583229]
# 		 4.6
# 			 mean : [0.07953978]
# 			 stddevs : [0.78107234]
# 			 mean_plus_1sd : [0.17369999]
# 			 mean_minus_1sd : [0.03642244]
# 		 4.8
# 			 mean : [0.11039215]
# 			 stddevs : [0.74156187]
# 			 mean_plus_1sd : [0.23173649]
# 			 mean_minus_1sd : [0.05258743]
# 		 5.0
# 			 mean : [0.15383232]
# 			 stddevs : [0.70224924]
# 			 mean_plus_1sd : [0.31047781]
# 			 mean_minus_1sd : [0.07621924]
# 		 5.2
# 			 mean : [0.21523484]
# 			 stddevs : [0.66316966]
# 			 mean_plus_1sd : [0.41775677]
# 			 mean_minus_1sd : [0.11089237]
# 		 5.4
# 			 mean : [0.30236614]
# 			 stddevs : [0.62436688]
# 			 mean_plus_1sd : [0.56453678]
# 			 mean_minus_1sd : [0.16194743]
# 		 5.6
# 			 mean : [0.36334932]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.66544144]
# 			 mean_minus_1sd : [0.19839872]
# 		 5.8
# 			 mean : [0.37236555]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.68195384]
# 			 mean_minus_1sd : [0.20332183]
# 		 6.0
# 			 mean : [0.38160551]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.69887599]
# 			 mean_minus_1sd : [0.2083671]
# 	 500
# 		 3.0
# 			 mean : [0.00664469]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.01480123]
# 			 mean_minus_1sd : [0.00298299]
# 		 3.2
# 			 mean : [0.00892994]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.0198917]
# 			 mean_minus_1sd : [0.0040089]
# 		 3.4
# 			 mean : [0.01204977]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.0268412]
# 			 mean_minus_1sd : [0.00540948]
# 		 3.6
# 			 mean : [0.01632541]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.03636531]
# 			 mean_minus_1sd : [0.00732893]
# 		 3.8
# 			 mean : [0.02220778]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.04946846]
# 			 mean_minus_1sd : [0.0099697]
# 		 4.0
# 			 mean : [0.03033205]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.06756551]
# 			 mean_minus_1sd : [0.01361691]
# 		 4.2
# 			 mean : [0.04159624]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.09265681]
# 			 mean_minus_1sd : [0.01867372]
# 		 4.4
# 			 mean : [0.05727458]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.12758076]
# 			 mean_minus_1sd : [0.02571217]
# 		 4.6
# 			 mean : [0.0791818]
# 			 stddevs : [0.78107234]
# 			 mean_plus_1sd : [0.17291823]
# 			 mean_minus_1sd : [0.03625851]
# 		 4.8
# 			 mean : [0.10991182]
# 			 stddevs : [0.74156187]
# 			 mean_plus_1sd : [0.23072818]
# 			 mean_minus_1sd : [0.05235862]
# 		 5.0
# 			 mean : [0.15318599]
# 			 stddevs : [0.70224924]
# 			 mean_plus_1sd : [0.30917332]
# 			 mean_minus_1sd : [0.075899]
# 		 5.2
# 			 mean : [0.21436272]
# 			 stddevs : [0.66316966]
# 			 mean_plus_1sd : [0.41606404]
# 			 mean_minus_1sd : [0.11044303]
# 		 5.4
# 			 mean : [0.3011862]
# 			 stddevs : [0.62436688]
# 			 mean_plus_1sd : [0.56233376]
# 			 mean_minus_1sd : [0.16131545]
# 		 5.6
# 			 mean : [0.36198577]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.66294422]
# 			 mean_minus_1sd : [0.19765419]
# 		 5.8
# 			 mean : [0.37102389]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.67949672]
# 			 mean_minus_1sd : [0.20258925]
# 		 6.0
# 			 mean : [0.38028767]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.6964625]
# 			 mean_minus_1sd : [0.20764753]
# 	 750
# 		 3.0
# 			 mean : [0.00657179]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.01463885]
# 			 mean_minus_1sd : [0.00295026]
# 		 3.2
# 			 mean : [0.00883454]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.01967918]
# 			 mean_minus_1sd : [0.00396607]
# 		 3.4
# 			 mean : [0.01192449]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.02656213]
# 			 mean_minus_1sd : [0.00535324]
# 		 3.6
# 			 mean : [0.01616036]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.03599767]
# 			 mean_minus_1sd : [0.00725484]
# 		 3.8
# 			 mean : [0.02198964]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.04898255]
# 			 mean_minus_1sd : [0.00987177]
# 		 4.0
# 			 mean : [0.03004283]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.06692125]
# 			 mean_minus_1sd : [0.01348707]
# 		 4.2
# 			 mean : [0.04121155]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.0917999]
# 			 mean_minus_1sd : [0.01850102]
# 		 4.4
# 			 mean : [0.05676136]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.12643754]
# 			 mean_minus_1sd : [0.02548177]
# 		 4.6
# 			 mean : [0.07849503]
# 			 stddevs : [0.78107234]
# 			 mean_plus_1sd : [0.17141846]
# 			 mean_minus_1sd : [0.03594403]
# 		 4.8
# 			 mean : [0.10899013]
# 			 stddevs : [0.74156187]
# 			 mean_plus_1sd : [0.22879335]
# 			 mean_minus_1sd : [0.05191955]
# 		 5.0
# 			 mean : [0.15194547]
# 			 stddevs : [0.70224924]
# 			 mean_plus_1sd : [0.3066696]
# 			 mean_minus_1sd : [0.07528436]
# 		 5.2
# 			 mean : [0.21268846]
# 			 stddevs : [0.66316966]
# 			 mean_plus_1sd : [0.41281441]
# 			 mean_minus_1sd : [0.10958043]
# 		 5.4
# 			 mean : [0.29892049]
# 			 stddevs : [0.62436688]
# 			 mean_plus_1sd : [0.55810354]
# 			 mean_minus_1sd : [0.16010194]
# 		 5.6
# 			 mean : [0.35936691]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.658148]
# 			 mean_minus_1sd : [0.19622421]
# 		 5.8
# 			 mean : [0.36844648]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.67477642]
# 			 mean_minus_1sd : [0.20118191]
# 		 6.0
# 			 mean : [0.37775545]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.69182495]
# 			 mean_minus_1sd : [0.20626486]
# 	 1000
# 		 3.0
# 			 mean : [0.00647283]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.01441842]
# 			 mean_minus_1sd : [0.00290584]
# 		 3.2
# 			 mean : [0.00870498]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.01939059]
# 			 mean_minus_1sd : [0.00390791]
# 		 3.4
# 			 mean : [0.0117543]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.02618304]
# 			 mean_minus_1sd : [0.00527684]
# 		 3.6
# 			 mean : [0.01593608]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.03549807]
# 			 mean_minus_1sd : [0.00715415]
# 		 3.8
# 			 mean : [0.02169311]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.04832201]
# 			 mean_minus_1sd : [0.00973864]
# 		 4.0
# 			 mean : [0.02964951]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.06604513]
# 			 mean_minus_1sd : [0.0133105]
# 		 4.2
# 			 mean : [0.04068825]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.09063422]
# 			 mean_minus_1sd : [0.0182661]
# 		 4.4
# 			 mean : [0.05606295]
# 			 stddevs : [0.80089263]
# 			 mean_plus_1sd : [0.12488182]
# 			 mean_minus_1sd : [0.02516823]
# 		 4.6
# 			 mean : [0.07756014]
# 			 stddevs : [0.78107234]
# 			 mean_plus_1sd : [0.16937682]
# 			 mean_minus_1sd : [0.03551593]
# 		 4.8
# 			 mean : [0.10773498]
# 			 stddevs : [0.74156187]
# 			 mean_plus_1sd : [0.22615853]
# 			 mean_minus_1sd : [0.05132164]
# 		 5.0
# 			 mean : [0.15025555]
# 			 stddevs : [0.70224924]
# 			 mean_plus_1sd : [0.30325886]
# 			 mean_minus_1sd : [0.07444706]
# 		 5.2
# 			 mean : [0.21040686]
# 			 stddevs : [0.66316966]
# 			 mean_plus_1sd : [0.40838597]
# 			 mean_minus_1sd : [0.10840491]
# 		 5.4
# 			 mean : [0.29583179]
# 			 stddevs : [0.62436688]
# 			 mean_plus_1sd : [0.55233675]
# 			 mean_minus_1sd : [0.15844763]
# 		 5.6
# 			 mean : [0.35579549]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.65160727]
# 			 mean_minus_1sd : [0.19427412]
# 		 5.8
# 			 mean : [0.36493033]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.66833691]
# 			 mean_minus_1sd : [0.19926199]
# 		 6.0
# 			 mean : [0.3742997]
# 			 stddevs : [0.60508594]
# 			 mean_plus_1sd : [0.68549607]
# 			 mean_minus_1sd : [0.20437793]
# ChiouYoungs2014
# 	 300
# 		 3.0
# 			 mean : [0.0082474]
# 			 stddevs : [0.77071596]
# 			 mean_plus_1sd : [0.01782522]
# 			 mean_minus_1sd : [0.00381592]
# 		 3.2
# 			 mean : [0.0121802]
# 			 stddevs : [0.77063258]
# 			 mean_plus_1sd : [0.02632303]
# 			 mean_minus_1sd : [0.00563603]
# 		 3.4
# 			 mean : [0.01768315]
# 			 stddevs : [0.77052375]
# 			 mean_plus_1sd : [0.03821148]
# 			 mean_minus_1sd : [0.00818324]
# 		 3.6
# 			 mean : [0.02518957]
# 			 stddevs : [0.77038835]
# 			 mean_plus_1sd : [0.05442471]
# 			 mean_minus_1sd : [0.01165857]
# 		 3.8
# 			 mean : [0.03523076]
# 			 stddevs : [0.77022735]
# 			 mean_plus_1sd : [0.0761075]
# 			 mean_minus_1sd : [0.01630859]
# 		 4.0
# 			 mean : [0.04842473]
# 			 stddevs : [0.77004455]
# 			 mean_plus_1sd : [0.10459075]
# 			 mean_minus_1sd : [0.02242028]
# 		 4.2
# 			 mean : [0.06548685]
# 			 stddevs : [0.76984619]
# 			 mean_plus_1sd : [0.14141453]
# 			 mean_minus_1sd : [0.03032593]
# 		 4.4
# 			 mean : [0.08724769]
# 			 stddevs : [0.76964007]
# 			 mean_plus_1sd : [0.1883668]
# 			 mean_minus_1sd : [0.04041136]
# 		 4.6
# 			 mean : [0.11629259]
# 			 stddevs : [0.76942354]
# 			 mean_plus_1sd : [0.25102007]
# 			 mean_minus_1sd : [0.05387604]
# 		 4.8
# 			 mean : [0.16614232]
# 			 stddevs : [0.76915365]
# 			 mean_plus_1sd : [0.358525]
# 			 mean_minus_1sd : [0.0769912]
# 		 5.0
# 			 mean : [0.23648245]
# 			 stddevs : [0.76890059]
# 			 mean_plus_1sd : [0.5101856]
# 			 mean_minus_1sd : [0.10961491]
# 		 5.2
# 			 mean : [0.29700673]
# 			 stddevs : [0.74158312]
# 			 mean_plus_1sd : [0.62349324]
# 			 mean_minus_1sd : [0.14148188]
# 		 5.4
# 			 mean : [0.34747796]
# 			 stddevs : [0.71436775]
# 			 mean_plus_1sd : [0.70986088]
# 			 mean_minus_1sd : [0.17009098]
# 		 5.6
# 			 mean : [0.39146225]
# 			 stddevs : [0.68722912]
# 			 mean_plus_1sd : [0.7783048]
# 			 mean_minus_1sd : [0.19689291]
# 		 5.8
# 			 mean : [0.42851119]
# 			 stddevs : [0.66016235]
# 			 mean_plus_1sd : [0.82921479]
# 			 mean_minus_1sd : [0.22144063]
# 		 6.0
# 			 mean : [0.47703801]
# 			 stddevs : [0.63315154]
# 			 mean_plus_1sd : [0.89851887]
# 			 mean_minus_1sd : [0.25326709]
# 	 500
# 		 3.0
# 			 mean : [0.00781462]
# 			 stddevs : [0.77072545]
# 			 mean_plus_1sd : [0.01689]
# 			 mean_minus_1sd : [0.00361565]
# 		 3.2
# 			 mean : [0.01154201]
# 			 stddevs : [0.77064578]
# 			 mean_plus_1sd : [0.02494415]
# 			 mean_minus_1sd : [0.00534065]
# 		 3.4
# 			 mean : [0.01676624]
# 			 stddevs : [0.77054129]
# 			 mean_plus_1sd : [0.03623077]
# 			 mean_minus_1sd : [0.00775879]
# 		 3.6
# 			 mean : [0.02390975]
# 			 stddevs : [0.77041045]
# 			 mean_plus_1sd : [0.05166067]
# 			 mean_minus_1sd : [0.01106598]
# 		 3.8
# 			 mean : [0.03349373]
# 			 stddevs : [0.77025372]
# 			 mean_plus_1sd : [0.07235698]
# 			 mean_minus_1sd : [0.0155041]
# 		 4.0
# 			 mean : [0.04612932]
# 			 stddevs : [0.77007429]
# 			 mean_plus_1sd : [0.09963595]
# 			 mean_minus_1sd : [0.02135689]
# 		 4.2
# 			 mean : [0.06252889]
# 			 stddevs : [0.76987796]
# 			 mean_plus_1sd : [0.1350313]
# 			 mean_minus_1sd : [0.02895522]
# 		 4.4
# 			 mean : [0.08352508]
# 			 stddevs : [0.76967224]
# 			 mean_plus_1sd : [0.18033554]
# 			 mean_minus_1sd : [0.03868588]
# 		 4.6
# 			 mean : [0.11162795]
# 			 stddevs : [0.76945469]
# 			 mean_plus_1sd : [0.24095885]
# 			 mean_minus_1sd : [0.05171339]
# 		 4.8
# 			 mean : [0.15975568]
# 			 stddevs : [0.7691829]
# 			 mean_plus_1sd : [0.34475311]
# 			 mean_minus_1sd : [0.07402943]
# 		 5.0
# 			 mean : [0.22767938]
# 			 stddevs : [0.76892668]
# 			 mean_plus_1sd : [0.49120673]
# 			 mean_minus_1sd : [0.10553174]
# 		 5.2
# 			 mean : [0.2863416]
# 			 stddevs : [0.74160535]
# 			 mean_plus_1sd : [0.60111775]
# 			 mean_minus_1sd : [0.13639842]
# 		 5.4
# 			 mean : [0.33556067]
# 			 stddevs : [0.71438673]
# 			 mean_plus_1sd : [0.68552811]
# 			 mean_minus_1sd : [0.16425434]
# 		 5.6
# 			 mean : [0.37876953]
# 			 stddevs : [0.68724527]
# 			 mean_plus_1sd : [0.7530813]
# 			 mean_minus_1sd : [0.1905058]
# 		 5.8
# 			 mean : [0.41548746]
# 			 stddevs : [0.66017611]
# 			 mean_plus_1sd : [0.80402354]
# 			 mean_minus_1sd : [0.21470743]
# 		 6.0
# 			 mean : [0.46353826]
# 			 stddevs : [0.63316301]
# 			 mean_plus_1sd : [0.8731016]
# 			 mean_minus_1sd : [0.24609704]
# 	 750
# 		 3.0
# 			 mean : [0.0073215]
# 			 stddevs : [0.77073633]
# 			 mean_plus_1sd : [0.01582438]
# 			 mean_minus_1sd : [0.00338746]
# 		 3.2
# 			 mean : [0.01081475]
# 			 stddevs : [0.77066098]
# 			 mean_plus_1sd : [0.02337278]
# 			 mean_minus_1sd : [0.00500406]
# 		 3.4
# 			 mean : [0.01572037]
# 			 stddevs : [0.77056157]
# 			 mean_plus_1sd : [0.03397139]
# 			 mean_minus_1sd : [0.00727465]
# 		 3.6
# 			 mean : [0.02244725]
# 			 stddevs : [0.77043619]
# 			 mean_plus_1sd : [0.04850197]
# 			 mean_minus_1sd : [0.01038884]
# 		 3.8
# 			 mean : [0.03150353]
# 			 stddevs : [0.77028466]
# 			 mean_plus_1sd : [0.06805963]
# 			 mean_minus_1sd : [0.01458239]
# 		 4.0
# 			 mean : [0.04349057]
# 			 stddevs : [0.77010951]
# 			 mean_plus_1sd : [0.09393975]
# 			 mean_minus_1sd : [0.0201345]
# 		 4.2
# 			 mean : [0.0591151]
# 			 stddevs : [0.76991591]
# 			 mean_plus_1sd : [0.12766407]
# 			 mean_minus_1sd : [0.02737337]
# 		 4.4
# 			 mean : [0.07920991]
# 			 stddevs : [0.76971102]
# 			 mean_plus_1sd : [0.17102546]
# 			 mean_minus_1sd : [0.03668582]
# 		 4.6
# 			 mean : [0.10619549]
# 			 stddevs : [0.76949257]
# 			 mean_plus_1sd : [0.22924107]
# 			 mean_minus_1sd : [0.04919485]
# 		 4.8
# 			 mean : [0.15228522]
# 			 stddevs : [0.76921883]
# 			 mean_plus_1sd : [0.32864365]
# 			 mean_minus_1sd : [0.07056515]
# 		 5.0
# 			 mean : [0.21733967]
# 			 stddevs : [0.76895905]
# 			 mean_plus_1sd : [0.46891453]
# 			 mean_minus_1sd : [0.10073592]
# 		 5.2
# 			 mean : [0.27376281]
# 			 stddevs : [0.74163312]
# 			 mean_plus_1sd : [0.57472702]
# 			 mean_minus_1sd : [0.13040291]
# 		 5.4
# 			 mean : [0.32144519]
# 			 stddevs : [0.71441052]
# 			 mean_plus_1sd : [0.65670674]
# 			 mean_minus_1sd : [0.15734117]
# 		 5.6
# 			 mean : [0.36367015]
# 			 stddevs : [0.68726559]
# 			 mean_plus_1sd : [0.72307495]
# 			 mean_minus_1sd : [0.18290771]
# 		 5.8
# 			 mean : [0.39992645]
# 			 stddevs : [0.66019346]
# 			 mean_plus_1sd : [0.77392434]
# 			 mean_minus_1sd : [0.20666254]
# 		 6.0
# 			 mean : [0.44733847]
# 			 stddevs : [0.6331775]
# 			 mean_plus_1sd : [0.84260056]
# 			 mean_minus_1sd : [0.23749297]
# 	 1000
# 		 3.0
# 			 mean : [0.00687582]
# 			 stddevs : [0.77074623]
# 			 mean_plus_1sd : [0.01486125]
# 			 mean_minus_1sd : [0.00318122]
# 		 3.2
# 			 mean : [0.01015735]
# 			 stddevs : [0.77067485]
# 			 mean_plus_1sd : [0.02195232]
# 			 mean_minus_1sd : [0.00469981]
# 		 3.4
# 			 mean : [0.01477403]
# 			 stddevs : [0.7705802]
# 			 mean_plus_1sd : [0.03192698]
# 			 mean_minus_1sd : [0.0068366]
# 		 3.6
# 			 mean : [0.02112145]
# 			 stddevs : [0.77045997]
# 			 mean_plus_1sd : [0.04563838]
# 			 mean_minus_1sd : [0.00977501]
# 		 3.8
# 			 mean : [0.02969444]
# 			 stddevs : [0.77031349]
# 			 mean_plus_1sd : [0.06415316]
# 			 mean_minus_1sd : [0.0137446]
# 		 4.0
# 			 mean : [0.04108368]
# 			 stddevs : [0.77014262]
# 			 mean_plus_1sd : [0.08874379]
# 			 mean_minus_1sd : [0.01901957]
# 		 4.2
# 			 mean : [0.05598865]
# 			 stddevs : [0.76995193]
# 			 mean_plus_1sd : [0.12091659]
# 			 mean_minus_1sd : [0.02592472]
# 		 4.4
# 			 mean : [0.07523998]
# 			 stddevs : [0.76974819]
# 			 mean_plus_1sd : [0.16245986]
# 			 mean_minus_1sd : [0.03484587]
# 		 4.6
# 			 mean : [0.10117351]
# 			 stddevs : [0.76952922]
# 			 mean_plus_1sd : [0.21840829]
# 			 mean_minus_1sd : [0.04686672]
# 		 4.8
# 			 mean : [0.14534797]
# 			 stddevs : [0.769254]
# 			 mean_plus_1sd : [0.31368355]
# 			 mean_minus_1sd : [0.06734823]
# 		 5.0
# 			 mean : [0.20769668]
# 			 stddevs : [0.76899108]
# 			 mean_plus_1sd : [0.44812393]
# 			 mean_minus_1sd : [0.09626335]
# 		 5.2
# 			 mean : [0.26198112]
# 			 stddevs : [0.74166078]
# 			 mean_plus_1sd : [0.55000822]
# 			 mean_minus_1sd : [0.12478742]
# 		 5.4
# 			 mean : [0.30816581]
# 			 stddevs : [0.71443433]
# 			 mean_plus_1sd : [0.62959221]
# 			 mean_minus_1sd : [0.15083759]
# 		 5.6
# 			 mean : [0.34940113]
# 			 stddevs : [0.687286]
# 			 mean_plus_1sd : [0.69471843]
# 			 mean_minus_1sd : [0.17572752]
# 		 5.8
# 			 mean : [0.3851546]
# 			 stddevs : [0.66021091]
# 			 mean_plus_1sd : [0.74535135]
# 			 mean_minus_1sd : [0.19902569]
# 		 6.0
# 			 mean : [0.43189144]
# 			 stddevs : [0.6331921]
# 			 mean_plus_1sd : [0.81351662]
# 			 mean_minus_1sd : [0.22928876]

# %% [markdown]
# ## Create table with PGA results for report

# %%
df = pd.DataFrame(columns=['gmm', 'distance', 'magnitude', 'Median PGA'])
gmms = []
dists = []
mags = []
means = []
means_plus_one = []
for gmm in gmm_results.keys():
    for dist in gmm_results[gmm].keys():
        for mag in gmm_results[gmm][dist].keys():
            gmms.append(gmm)
            dists.append(dist)  
            mags.append(mag)
            means.append(gmm_results[gmm][dist][mag].get('mean')[0])
            means_plus_one.append(gmm_results[gmm][dist][mag].get('mean_plus_1sd')[0])
            
            
            
df['gmm'] = gmms
df['distance'] = dists
df['magnitude'] = mags
df['Median PGA'] = means
df['84th percentile PGA'] = means_plus_one
display(df)
df.to_excel(os.path.join(topdir,'full_output_by_gmm_table.xlsx'), index=False)
# Out:
#                     gmm  distance  magnitude  Median PGA  84th percentile PGA
# 0    McGarrFletcher2005       300        3.0    0.468911             1.425903
# 1    McGarrFletcher2005       300        3.2    0.703996             2.140770
# 2    McGarrFletcher2005       300        3.4    1.056939             3.214031
# 3    McGarrFletcher2005       300        3.6    1.586829             4.825363
# 4    McGarrFletcher2005       300        3.8    2.382374             7.244527
# ..                  ...       ...        ...         ...                  ...
# 763     ChiouYoungs2014      1000        5.2    0.261981             0.550008
# 764     ChiouYoungs2014      1000        5.4    0.308166             0.629592
# 765     ChiouYoungs2014      1000        5.6    0.349401             0.694718
# 766     ChiouYoungs2014      1000        5.8    0.385155             0.745351
# 767     ChiouYoungs2014      1000        6.0    0.431891             0.813517
#
# [768 rows x 5 columns]

# %% [markdown]
# # Plot PGA results

# %%
grouped_distance = df.groupby(['distance'])

from cycler import cycler
color_cycler = cycler('color', [plt.get_cmap('jet')(i/12) for i in range(12)])
plt.rc('axes', prop_cycle=color_cycler)
#fig,ax = plt.subplots(figsize=[15,15])

font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)

for distance, group_dist in grouped_distance:
    fig,ax = plt.subplots(figsize=[10,10])
    for gmm, group_gmm in group_dist.groupby(['gmm']):
        #print(group_gmm)
        if gmm.startswith('Douglas'):
            gmm_label = 'DouglasEtAl2013Stocastic'
        else:
            gmm_label = gmm
        mags = group_gmm['magnitude'].tolist()
        medians = group_gmm['Median PGA'].tolist()
        medians_plus_std = group_gmm['84th percentile PGA']
        ax.semilogy(mags,medians,label = gmm_label)
        ax.scatter(mags,medians,s=50,marker = 'x')
    ax.legend(bbox_to_anchor=(1.04,1) ,fontsize=12, title='Ground Motion Models', title_fontsize=14)
    ax.grid(which='both')
    ax.set_title('PGA at '+str(distance)+'m')
    ax.set_xlabel('Magnitude')
    ax.set_ylabel('Acceleration (g)')
    plt.savefig(os.path.join(figdir,'PGA_values_by_mag_at_'+str(distance)+'.png'),format='PNG', dpi=600, bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# # Plot weighted PGA results

# %%
display(df)
# Out:
#                     gmm  distance  magnitude  Median PGA  84th percentile PGA
# 0    McGarrFletcher2005       300        3.0    0.468911             1.425903
# 1    McGarrFletcher2005       300        3.2    0.703996             2.140770
# 2    McGarrFletcher2005       300        3.4    1.056939             3.214031
# 3    McGarrFletcher2005       300        3.6    1.586829             4.825363
# 4    McGarrFletcher2005       300        3.8    2.382374             7.244527
# ..                  ...       ...        ...         ...                  ...
# 763     ChiouYoungs2014      1000        5.2    0.261981             0.550008
# 764     ChiouYoungs2014      1000        5.4    0.308166             0.629592
# 765     ChiouYoungs2014      1000        5.6    0.349401             0.694718
# 766     ChiouYoungs2014      1000        5.8    0.385155             0.745351
# 767     ChiouYoungs2014      1000        6.0    0.431891             0.813517
#
# [768 rows x 5 columns]

# %%
gmms_weight_dict = {'McGarrFletcher2005' : ([0.3]*5) + ([0.0]*11),
                    'Atkinson2015' : ([0.3]*5) + ([0.4]*5) + ([0.0]*6),
                    'ZalachorisRathje2019' : ([0.2]*5) + ([0.2]*5) + ([0.0]*6),
                    'DostEtAl2004' : [0.0]*len(magnitudes), # trt = INDUCED
                    'DouglasEtAl2013StochasticSD001Q200K005' : [0.0]*len(magnitudes), 
                    'Allen2012' : ([0.0]*5) + ([0.1]*5) + ([(1/7)]*6), 
                    'AtkinsonBoore2006' : ([0.1]*5) + ([0.05]*5) + ([(1/7)]*6), 
                    'AtkinsonBoore2006Modified2011' : ([0.1]*5) + ([0.05]*5) + ([(1/7)]*6),
                    'SomervilleEtAl2009YilgarnCraton' : ([0.0]*10) + ([(1/7)]*6),  
                    'ZhaoEtAl2006AscSWISS05' : ([0.0]*5) + ([0.1]*5) + ([(1/7)]*6), 
                    'BooreEtAl2014' : ([0.0]*5) + ([0.05]*5) + ([(1/7)]*6),
                    'ChiouYoungs2014' : ([0.0]*5) + ([0.05]*5) + ([(1/7)]*6)
                   }

# %%
grouped_distance = df.groupby(['distance'])
df2 = pd.DataFrame(columns=['magnitude','distance','median','84th'])

for distance, group_dist in grouped_distance:
    fig,ax = plt.subplots(figsize=[10,10])
    weighted_median = []
    weighted_84th = []
    for gmm, group_gmm in group_dist.groupby(['gmm']):
        
        group_gmm['weights'] = gmms_weight_dict[gmm]
        
        # Calculate weighted median and 84th percentile PGAs
        weighted_gmm_medians = group_gmm['Median PGA'].to_numpy() * group_gmm['weights'].to_numpy()
        weighted_gmm_84th = group_gmm['84th percentile PGA'].to_numpy() * group_gmm['weights'].to_numpy()
        
        # Add the weighted median and 84th fractile values to the distance-grouped dataframe
        group_gmm['weighted_median'] = weighted_gmm_medians
        group_gmm['weighted_84th'] = weighted_gmm_84th
        #display(group_gmm)
        
        # Append to master list for summing
        weighted_median.append(weighted_gmm_medians)
        weighted_84th.append(weighted_gmm_84th)
        #ax.semilogy(magnitudes,weighted_gmm_medians,label = gmm)
    
    # Compute weighted sum of median and 84th percentiles for each magnitude/distance pair
    weighted_median = np.sum(np.asarray(weighted_median),axis=0)
    weighted_84th = np.sum(np.asarray(weighted_84th),axis=0)
    
    # Plot the weighted sums of the median and 84th percentiles
    ax.semilogy(magnitudes,weighted_median,label = 'Median', lw=2)
    ax.scatter(magnitudes,weighted_median,s=50,marker = 'x') #Add discrete points to the figure
    
    ax.semilogy(magnitudes, weighted_84th, label = '84th percentile')
    ax.scatter(magnitudes,weighted_84th,s=50,marker = 'x') # Add discrete points to the figure

    # Annotate the figure
    ax.legend(fontsize=12, title='Ground Motion Models', title_fontsize=14, loc='lower right')
    ax.grid(which='both')
    ax.axis([3,6.1,0.1,4])
    ax.set_title('Distance = '+str(distance)+'m')
    ax.set_xlabel('Magnitude')
    ax.set_ylabel('PGA (g)')
    ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    ax.set_yticks([0.1, 0.3,1,3])
    ax.set_yticklabels([0.1, 0.3,1,3])
    plt.savefig(os.path.join(figdir,'Weighted_PGA_by_mag_at_'+str(distance)+'.png'),format='PNG', dpi=600, bbox_inches='tight', pad_inches=0.1)

    # Create a table with the final values for the report
    for i,mag in enumerate(magnitudes):
        newrow = {'magnitude':mag, 'distance':distance,'median':weighted_median[i],'84th':weighted_84th[i]}
        df2 = df2.append(newrow, ignore_index=True)

display(df2)
df2.to_excel(os.path.join(topdir,'final_PGA_results.xlsx'),index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weights'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-b00ddf42368c> in <module>
#       8     for gmm, group_gmm in group_dist.groupby(['gmm']):
#       9         # Calculate weighted median and 84th percentile PGAs
# ---> 10         weighted_gmm_medians = group_gmm['Median PGA'].to_numpy() * group_gmm['weights'].to_numpy()
#      11         weighted_gmm_84th = group_gmm['84th percentile PGA'].to_numpy() * group_gmm['weights'].to_numpy()
#      12
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'weights'

# %% [markdown]
# # Calculate Spectra

# %%
# Initialise results directory
gmm_spectra_results = dict.fromkeys([str(x).replace('[','').replace(']','') for x in gmm_list])

for gmm in gmm_list:
    gmm_label = str(gmm).replace('[','').replace(']','')
    print(gmm_label)
    
    rctx = RuptureContext()
    rctx.dip = 45
    rctx.rake = 90
    sctx = SitesContext()
    sctx.vs30measured = 0 # 0 = inferred; 1 = measured
    dctx = DistancesContext()

    # Intensity measurements
    periods = np.logspace(-2., 1., 70)
    imts = [PGA()] + [SA(per) for per in periods[1:]]

    # StdDev type
    stddev_types = [const.StdDev.TOTAL]
    
    if gmm_label == 'ZalachorisRathje2019':
        sctx.vs30 = np.asarray([760.0])
        sctx.z1pt0 = np.asarray([33.7]) # Calculated from Kalakamos et al 2011
    else: 
        sctx.vs30 = np.asarray([800.0])
        sctx.z1pt0 = np.asarray([26.8]) # Calculated from Kalakamos et al 2011
        
    gmm_spectra_results[gmm_label] = dict.fromkeys(distances)
    for d in distances:
        dist_km = np.asarray([d/1000])
        dctx.rjb = dist_km
        dctx.rrup = dist_km
        dctx.rhypo = dist_km
        dctx.rx = dist_km
        rctx.hypo_depth = dist_km
        rctx.ztor = dist_km
        
        gmm_spectra_results[gmm_label][d] = dict.fromkeys(magnitudes)
        for m in magnitudes:
            rctx.mag = np.asarray([m])
            gmm_spectra_results[gmm_label][d][m] = calculate_ground_motions(gmm, sctx, rctx, dctx, imts, stddev_types)

# %% [markdown]
# ## Create table with spectra values

# %%
df_spectra = pd.DataFrame(columns=['gmm', 'distance', 'magnitude', 'Median spectra'])
gmms_spectra = []
dists_spectra = []
mags_spectra = []
means_spectra = []
means_plus_one_spectra = []
for gmm in gmm_spectra_results.keys():
    for dist in gmm_spectra_results[gmm].keys():
        for mag in gmm_spectra_results[gmm][dist].keys():
            gmms_spectra.append(gmm)
            dists_spectra.append(dist)  
            mags_spectra.append(mag)
            means_spectra.append(gmm_spectra_results[gmm][dist][mag].get('mean'))
            means_plus_one_spectra.append(gmm_spectra_results[gmm][dist][mag].get('mean_plus_1sd'))
        
df_spectra['gmm'] = gmms_spectra
df_spectra['distance'] = dists_spectra
df_spectra['magnitude'] = mags_spectra
df_spectra['Median spectra'] = means_spectra
df_spectra['84th percentile spectra'] = means_plus_one_spectra
display(df_spectra)
df_spectra.to_excel(os.path.join(topdir,'full_spectrum_output_table.xlsx'), index=False)

# %% [markdown]
# # Plot Spectra Results

# %%
grouped_dist_mag = df_spectra.groupby(['distance','magnitude'])

from cycler import cycler
color_cycler = cycler('color', [plt.get_cmap('jet')(i/12) for i in range(12)])
plt.rc('axes', prop_cycle=color_cycler)

#fig,ax = plt.subplots(figsize=[15,15])
plotting_periods = periods
for dist_mag, group_dist_mag in grouped_dist_mag:
    fig,ax = plt.subplots(figsize=[10,10])
    for gmm, group_spectra_gmm in group_dist_mag.groupby(['gmm']):
        #print(group_spectra_gmm['Median spectra'].to_numpy()[0])
        medians = group_spectra_gmm['Median spectra'].to_numpy()[0]
        medians_plus_std = group_spectra_gmm['84th percentile spectra'].to_numpy()[0]
        
        if gmm.startswith('Douglas'):
            gmm_label = 'DouglasEtAl2013Stocastic'
        else:
            gmm_label = gmm
        
        if np.count_nonzero(~np.isnan(medians)) == 1:
            ax.scatter(plotting_periods,medians,s=75,marker = 's', label=gmm_label + ' (PGA Only)')
        else:
            ax.loglog(plotting_periods,medians,label = gmm_label)
            #ax.scatter(plotting_periods,medians,s=15,marker = 'o')
            ax.scatter(plotting_periods[0],medians[0],s=50, marker='x')
            
    ax.legend(bbox_to_anchor=(1.04,1) ,fontsize=12, title='Ground Motion Models', title_fontsize=14)
    ax.grid(which='both')
    ax.axis([0.01,10,0.01,10])
    ax.set_title('Hazard spectra at '+str(dist_mag[0])+' m for M'+ str(dist_mag[1]))
    ax.set_xlabel('Spectral Period (s)')
    ax.set_ylabel('Acceleration (g)')
    ax.set_xticks([0.01,0.1,1,10])
    ax.set_xticklabels(['PGA',0.1,1,10])
    plt.savefig(os.path.join(figdir,'hazard_spectra_'+str(dist_mag[0])+'_'+str(dist_mag[1])+'.png'),format='PNG', dpi=600, bbox_inches='tight', pad_inches=0.1)
